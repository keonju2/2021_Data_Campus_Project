# %%
import pandas as pd

data=pd.read_csv('df_fin.csv')

# %%
data
# Out:
#             Date                                           기사제목    Close  \
# 0     2021-01-01  [낡은규제혁파①]"세계 최고 상속세율, 기업인에 사망선고"…재계, 상속세율 ...  83000.0
# 1     2021-01-01            [낡은규제혁파①]암세포 같은 낡은 규제가 한국 경제 혁신 막는다  83000.0
# 2     2021-01-01           머리카락 100배 얇은 초박막렌즈 개발…스마트폰 `카툭튀` 없앤다  83000.0
# 3     2021-01-01             1월효과, 연말랠리 잇는다…증권가 "실적개선·경기민감株 주목"  83000.0
# 4     2021-01-01  [낡은규제혁파①]"세계 최고 상속세율, 기업인에 사망선고"…재계, 상속세율 ...  83000.0
# ...          ...                                            ...      ...
# 5479  2021-06-29                  삼성전자 "美공장부지 선정 못했다"…핵심은 '칩스법'  80700.0
# 5480  2021-06-29         삼성 'SSAFY'·SK '하이파이브'…정부 지원으로 3천명+α 확대  80700.0
# 5481  2021-06-29               삼성전자, 2Q 영업익 11조원 초반대…반도체 견인-IBK  80700.0
# 5482  2021-06-29               삼성·LG전자, 2분기 실적도 '훨훨'…내주 잠정실적 발표  80700.0
# 5483  2021-06-29        삼성전자, 사내외 벤처 인큐베이팅 가동…5년동안 500개 프로젝트 육성  80700.0
#
#         Change   등락구분  label  주가 반영 Date
# 0     0.024691   True    1.0  2021-01-04
# ...

# %%
title_list=data.기사제목.values.tolist()

# %%
len(title_list)
title_list
# Out:
# ['[낡은규제혁파①]"세계 최고 상속세율, 기업인에 사망선고"…재계, 상속세율 ...',
#  '[낡은규제혁파①]암세포 같은 낡은 규제가 한국 경제 혁신 막는다',
#  '머리카락 100배 얇은 초박막렌즈 개발…스마트폰 `카툭튀` 없앤다',
#  '1월효과, 연말랠리 잇는다…증권가 "실적개선·경기민감株 주목"',
#  '[낡은규제혁파①]"세계 최고 상속세율, 기업인에 사망선고"…재계, 상속세율 ...',
#  '갤럭시S21, 이번엔 티저영상 유출…“새로운 갤럭시가 기다리고 있다”',
#  "[밑줄 쫙!] '국정농단' 대미 장식…특검, 이재용에 징역 9년 구형",
#  '코스피 시총, 사상 최초 GDP 넘어선 듯…삼전 150조원 증가',
#  '[2021 경제기상도] 코로나에 갇혔던 韓경제…소의 뿔처럼 저돌적 돌파 기대',
#  '[반도체] 메모리값 강세 지속…파운드리 수요도 늘듯',
#  '[디스플레이] 더 선명해진 LED…프리미엄TV 시장 선점',
#  '[가전] `집콕 수혜` 백색가전, 상반기까지 돌풍 예고',
#  '[스마트폰] 중저가 5G폰 라인업 확대…두자릿수 성장 노려',
#  '애플 5G폰, 출시 두달새 삼성 年판매량 추월',
#  "주식부호 '1조클럽' 25명…김범수 카카오의장 순위 껑충",
#  '[장기자의 비사이드IT]크리스마스는 아이폰이 접수?',
#  '`애플카` LG전자의 야심작 `LG롤러블` 이달 첫선…어떻게 생겼나',
#  '`슈퍼리치` 재테크…스타PB가 조언하는 올해 주목할 테마',
#  '"품질로 경쟁" 선언 반년 만에…‘QNED’ 명칭 놓고 삼성-LG 신경전',
#  '4대그룹 시무식 4일 ‘온라인’ 개최…이재용 신년사 없을 듯',
#  '[장기자의 비사이드IT]크리스마스는 아이폰이 접수?',
#  '[주목!e스몰캡]살아나는 반도체 업황…기회 찾아온 ‘아이원스’',
#  '[유안타證 주간추천주]‘매출 반등 예상’…삼성전자·아모레퍼시픽·엔씨소프...',
# ...

# %%
title_text=''
for each_line in title_list:
    title_text=title_text+each_line+'\n'


tokens_ko=twitter.morphs(title_text)
print(tokens_ko)
ko=nltk.Text(tokens_ko)
print(len(ko.tokens))
print(len(set(ko.tokens)))
# Out:
# ['[', '낡은규제', '혁파', '①', ']"', '세계', '최고', '상속세율', ',', '기업인', '에', '사망', '선고', '"…', '재계', ',', '상속세율', '...', '[', '낡은규제', '혁파', '①', ']', '암세포', '같은', '낡은', '규제', '가', '한국', '경제', '혁신', '막는다', '머리카락', '100', '배', '얇은', '초', '박막', '렌즈', '개발', '…', '스마트폰', '`', '카툭', '튀', '`', '없앤다', '1월', '효과', ',', '연말', '랠리', '잇는다', '…', '증권', '가', '"', '실적', '개선', '·', '경기', '민감', '株', '주목', '"', '[', '낡은규제', '혁파', '①', ']"', '세계', '최고', '상속세율', ',', '기업인', '에', '사망', '선고', '"…', '재계', ',', '상속세율', '...', '갤럭시', 'S', '21', ',', '이번', '엔', '티저', '영상', '유출', '…', '“', '새', '로운', '갤럭시', '가', '기', '다리', '고', '있다', '”', '[', '밑줄', '쫙', '!]', "'", '국정', '농단', "'", '대미', '장식', '…', '특검', ',', '이재용', '에', '징역', '9년', '구형', '코스피', '시', '총', ',', '사상', '최초', 'GDP', '넘', '어선', '듯', '…', '삼전', '150조원', '증가', '[', '2021', '경제', '기상도', ']', '코로나', '에', '갇혔던', '韓', '경제', '…', '소의', '뿔', '처럼', '저돌', '적', '돌파', '기대', '[', '반도체', ']', '메모리', '값', '강세', '지속', '…', '파운드리', '수요', '도', '늘듯', '[', '디스플레이', ']', '더', '
# ...

# %%
print(ko.vocab().most_common(200))
# Out:
# [("'", 2560), (',', 2451), ('…', 2093), ('삼성', 2057), ('"', 1623), ('[', 1211), ('전자', 1159), (']', 1115), ('·', 1084), ('에', 1018), ('반도체', 581), ('코스피', 518), ('‘', 494), ('’', 431), ('는', 378), ('이재용', 377), ('`', 374), ('의', 372), ('한', 349), ('이', 302), ('-', 298), ('1', 298), ('가', 290), ('선', 289), ('투자', 272), ('위', 269), ('"…', 266), ('은', 263), ('도', 258), ('로', 250), ('주', 250), ('“', 249), ('”', 249), ('美', 234), ('?', 228), ('기업', 215), ('...', 208), ('갤럭시', 206), ('SK', 197), ('상승', 178), ('마감', 176), ('실적', 174), ('LG', 165), ('대', 165), (')', 160), ('2', 159), ('출시', 153), ('…"', 152), ('5', 151), ('3', 150), ('기관', 145), ('다', 141), ('서', 141), ('포토', 141), ('장', 139), ('S', 138), ('(', 137), ('↑', 135), ('G', 134), ('매수', 133), ('개미', 133), ('사면', 131), ('코로나', 129), ('해', 128), ('으로', 128), ('분기', 127), ('까지', 122), ('4', 122), ('들', 122), ('하락', 120), ('외국인', 118), ('와', 117), ('시장', 116), ('비', 116), ('21', 114), ('더', 114), ("'…", 114), ("…'", 113), ('한국', 112),
# ...
