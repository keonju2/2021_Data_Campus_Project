# %%
import pandas as pd

data=pd.read_csv('df_fin.csv')

# %%
from konlpy.tag import Okt
from nltk.tokenize import word_tokenize 
import re
okt=Okt()

# %%
stopwords='아 휴 아이구 아이쿠 아이고 어 나 우리 저희 따라 의해 을 를 에 의 가 으로 로 에게 뿐이다 의거하여 근거하여 입각하여 기준으로 예하면 예를 들면 예를 들자면 저 소인 소생 저희 지말고 하지마 하지마라 다른 물론 또한 그리고 비길수 없다 해서는 안된다 뿐만 아니라 만이 아니다 만은 아니다 막론하고 관계없이 그치지 않다 그러나 그런데 하지만 든간에 논하지 않다 따지지 않다 설사 비록 더라도 아니면 만 못하다 하는 편이 낫다 불문하고 향하여 향해서 향하다 쪽으로 틈타 이용하여 타다 오르다 제외하고 이 외에 이 밖에 하여야 비로소 한다면 몰라도 외에도 이곳 여기 부터 기점으로 따라서 할 생각이다 하려고하다 이리하여 그리하여 그렇게 함으로써 하지만 일때 할때 앞에서 중에서 보는데서 으로써 로써 까지 해야한다 일것이다 반드시 할줄알다 할수있다 할수있어 임에 틀림없다 한다면 등 등등 제 겨우 단지 다만 할뿐 딩동 댕그 대해서 대하여 대하면 훨씬 얼마나 얼마만큼 얼마큼 남짓 여 얼마간 약간 다소 좀 조금 다수 몇 얼마 지만 하물며 또한 그러나 그렇지만 하지만 이외에도 대해 말하자면 뿐이다 다음에 반대로 반대로 말하자면 이와 반대로 바꾸어서 말하면 바꾸어서 한다면 만약 그렇지않으면 까악 툭 딱 삐걱거리다 보드득 비걱거리다 꽈당 응당 해야한다 에 가서 각 각각 여러분 각종 각자 제각기 하도록하다 와 과 그러므로 그래서 고로 한 까닭에 하기 때문에 거니와 이지만 대하여 관하여 관한 과연 실로 아니나다를가 생각한대로 진짜로 한적이있다 하곤하였다 하 하하 허허 아하 거바 와 오 왜 어째서 무엇때문에 어찌 하겠는가 무슨 어디 어느곳 더군다나 하물며 더욱이는 어느때 언제 야 이봐 어이 여보시오 흐흐 흥 휴 헉헉 헐떡헐떡 영차 여차 어기여차 끙끙 아야 앗 아야 콸콸 졸졸 좍좍 뚝뚝 주룩주룩 솨 우르르 그래도 또 그리고 바꾸어말하면 바꾸어말하자면 혹은 혹시 답다 및 그에 따르는 때가 되어 즉 지든지 설령 가령 하더라도 할지라도 일지라도 지든지 몇 거의 하마터면 인젠 이젠 된바에야 된이상 만큼 어찌됏든 그위에 게다가 점에서 보아 비추어 보아 고려하면 하게될것이다 일것이다 비교적 좀 보다더 비하면 시키다 하게하다 할만하다 의해서 연이서 이어서 잇따라 뒤따라 뒤이어 결국 의지하여 기대여 통하여 자마자 더욱더 불구하고 얼마든지 마음대로 주저하지 않고 곧 즉시 바로 당장 하자마자 밖에 안된다 하면된다 그래 그렇지 요컨대 다시 말하자면 바꿔 말하면 즉 구체적으로 말하자면 시작하여 시초에 이상 허 헉 허걱 바와같이 해도좋다 해도된다 게다가 더구나 하물며 와르르 팍 퍽 펄렁 동안 이래 하고있었다 이었다 에서 로부터 까지 예하면 했어요 해요 함께 같이 더불어 마저 마저도 양자 모두 습니다 가까스로 하려고하다 즈음하여 다른 다른 방면으로 해봐요 습니까 했어요 말할것도 없고 무릎쓰고 개의치않고 하는것만 못하다 하는것이 낫다 매 매번 들 모 어느것 어느 로써 갖고말하자면 어디 어느쪽 어느것 어느해 어느 년도 라 해도 언젠가 어떤것 어느것 저기 저쪽 저것 그때 그럼 그러면 요만한걸 그래 그때 저것만큼 그저 이르기까지 할 줄 안다 할 힘이 있다 너 너희 당신 어찌 설마 차라리 할지언정 할지라도 할망정 할지언정 구토하다 게우다 토하다 메쓰겁다 옆사람 퉤 쳇 의거하여 근거하여 의해 따라 힘입어 그 다음 버금 두번째로 기타 첫번째로 나머지는 그중에서 견지에서 형식으로 쓰여 입장에서 위해서 단지 의해되다 하도록시키다 뿐만아니라 반대로 전후 전자 앞의것 잠시 잠깐 하면서 그렇지만 다음에 그러한즉 그런즉 남들 아무거나 어찌하든지 같다 비슷하다 예컨대 이럴정도로 어떻게 만약 만일 위에서 서술한바와같이 인 듯하다 하지 않는다면 만약에 무엇 무슨 어느 어떤 아래윗 조차 한데 그럼에도 불구하고 여전히 심지어 까지도 조차도 하지 않도록 않기 위하여 때 시각 무렵 시간 동안 어때 어떠한 하여금 네 예 우선 누구 누가 알겠는가 아무도 줄은모른다 줄은 몰랏다 하는 김에 겸사겸사 하는바 그런 까닭에 한 이유는 그러니 그러니까 때문에 그 너희 그들 너희들 타인 것 것들 너 위하여 공동으로 동시에 하기 위하여 어찌하여 무엇때문에 붕붕 윙윙 나 우리 엉엉 휘익 윙윙 오호 아하 어쨋든 만 못하다 하기보다는 차라리 하는 편이 낫다 흐흐 놀라다 상대적으로 말하자면 마치 아니라면 쉿 그렇지 않으면 그렇지 않다면 안 그러면 아니었다면 하든지 아니면 이라면 좋아 알았어 하는것도 그만이다 어쩔수 없다 하나 일 일반적으로 일단 한켠으로는 오자마자 이렇게되면 이와같다면 전부 한마디 한항목 근거로 하기에 아울러 하지 않도록 않기 위해서 이르기까지 이 되다 로 인하여 까닭으로 이유만으로 이로 인하여 그래서 이 때문에 그러므로 그런 까닭에 알 수 있다 결론을 낼 수 있다 으로 인하여 있다 어떤것 관계가 있다 관련이 있다 연관되다 어떤것들 에 대해 이리하여 그리하여 여부 하기보다는 하느니 하면 할수록 운운 이러이러하다 하구나 하도다 다시말하면 다음으로 에 있다 에 달려 있다 우리 우리들 오히려 하기는한데 어떻게 어떻해 어찌됏어 어때 어째서 본대로 자 이 이쪽 여기 이것 이번 이렇게말하자면 이런 이러한 이와 같은 요만큼 요만한 것 얼마 안 되는 것 이만큼 이 정도의 이렇게 많은 것 이와 같다 이때 이렇구나 것과 같이 끼익 삐걱 따위 와 같은 사람들 부류의 사람들 왜냐하면 중의하나 오직 오로지 에 한하다 하기만 하면 도착하다 까지 미치다 도달하다 정도에 이르다 할 지경이다 결과에 이르다 관해서는 여러분 하고 있다 한 후 혼자 자기 자기집 자신 우에 종합한것과같이 총적으로 보면 총적으로 말하면 총적으로 대로 하다 으로서 참 그만이다 할 따름이다 쿵 탕탕 쾅쾅 둥둥 봐 봐라 아이야 아니 와아 응 아이 참나 년 월 일 령 영 일 이 삼 사 오 육 륙 칠 팔 구 이천육 이천칠 이천팔 이천구 하나 둘 셋 넷 다섯 여섯 일곱 여덟 아홉 령 영 이 있 하 것 들 그 되 수 이 보 않 없 나 사람 주 아니 등 같 우리 때 년 가 한 지 대하 오 말 일 그렇 위하 때문 그것 두 말하 알 그러나 받 못하 일 그런 또 문제 더 사회 많 그리고 좋 크 따르 중 나오 가지 씨 시키 만들 지금 생각하 그러 속 하나 집 살 모르 적 월 데 자신 안 어떤 내 내 경우 명 생각 시간 그녀 다시 이런 앞 보이 번 나 다른 어떻 여자 개 전 들 사실 이렇 점 싶 말 정도 좀 원 잘 통하 놓'

stopwords=stopwords.split(' ')

# %%
lists=[]
for i in range(len(data['Date'])):
    text=data.iloc[i]['기사제목']
    text=re.sub(r'[@%\\*=()/~#&\+á?\xc3\xa1\-\|\.\:\;\!\-\,\_\~\$\'\"]','',text)
    text = re.sub(r'\d+','',text)# remove number
    text = text.lower() #lower case
    text = re.sub(r'\s+', ' ', text) #remove extra space
    text = re.sub(r'<[^>]+>','',text) #remove Html tags
    text = re.sub(r'\s+', ' ', text) #remove spaces
    text = re.sub(r"^\s+", '', text) #remove space from start
    text = re.sub(r'\s+$', '', text)
    hangul = re.compile('[^ ㄱ-ㅣ가-힣]+')
    result=hangul.sub('',text)
    if result not in stopwords:
        results=okt.morphs(result)
        lists.append(results)
        
    
data['형태소분석']=lists

# %%
news_title=data['형태소분석']

# %%
news_list=[]
for i in range(len(news_title)):
    list1=[]
    for j in range(len(news_title[i])):
        list1.append(news_title[i][j])
    news_list.append(' '.join(list1))
news_list
# Out:
# ['낡은 규 제혁 파세계 최고 상속 세율 기업인 에 사망 선고 재계 상속 세율',
#  '낡은 규 제혁 파 암세포 같은 낡은 규제 가 한국 경제 혁신 막는다',
#  '머리카락 배 얇은 초 박막 렌즈 개발 스마트폰 카툭 튀 없앤다',
#  '월 효과 연말 랠리 잇는다 증권 가 실적 개선 경기 민감 주목',
#  '낡은 규 제혁 파세계 최고 상속 세율 기업인 에 사망 선고 재계 상속 세율',
#  '갤럭시 이번 엔 티저 영상 유출 새로운 갤럭시 가 기다리고 있다',
#  '밑줄 쫙 국정 농단 대미 장식 특검 이재용 에 징역 년 구형',
#  '코스피 시 총 사상 최초 넘어선 듯 삼전 조원 증가',
#  '경제 기상도 코로나 에 갇혔던 경제 소의 뿔 처럼 저돌 적 돌파 기대',
#  '반도체 메모리 값 강세 지 속 파운드리 수요 도 늘듯',
#  '디스플레이 더 선명해진 프리미엄 시장 선점',
#  '가전 집콕 수혜 백색 가전 상반기 까지 돌풍 예고',
#  '스마트폰 중 저가 폰 라인업 확대 두 자릿수 성장 노려',
#  '애플 폰 출시 두 달새 삼성 판매량 추월',
#  '주식 부호 조 클럽 명 김범수 카카오 의장 순위 껑충',
#  '장기 자의 비사 이드 크리스마스 는 아이폰 이 접수',
#  '애플 카 전자 의 야심작 롤러 블 이 달 첫 선 어떻게 생겼나',
#  '슈퍼 리치 재테크 스타 가 조언 하는 올해 주목 할 테마',
#  '품질 로 경쟁 선언 반년 만에 명칭 놓고 삼성 신 경전',
#  '대 그룹 시무 식 일 온라인 개최 이재용 신년사 없을 듯',
#  '장기 자의 비사 이드 크리스마스 는 아이폰 이 접수',
#  '주목 스몰 캡 살아나는 반도체 업황 기회 찾아온 아이 원스',
#  '유 안타 주간 추천 주 매출 반등 예상 삼 성전 자 아모레퍼시픽 엔씨 소프',
#  '단독 주린이 삼성로 몰리나 현대차 배터리 공급 후보 낙점',
#  '삼성 전자 여전히 저 평가 전문가 새해 톱픽 추천',
#  '삼성 패스 로 연말정산 을 전자서명 시장 본격 진출',
#  '국내 가입자 천만 명 돌파 올해 대중화 단계',
#  '펀드 와 치 사상 최고 치 코스피 레버리지 펀드 껑충',
#  '국내 가입자 천만 명 돌파 제재 로 새해 폰 애플 위',
#  '주 간증 시 전망 어 닝 시즌 진입 월 효과 시동 걸까',
#  '이재용 부회장 경영 에 전념 하게 해달라 국민 청원 등장',
#  '스페셜 리포트 삼성 명 포스코 명 시가총액 증가 기업 사장 승진 많았다',
#  '코스피 주간 외국인 순 매도 위 삼성 전자',
#  '코스피 주간 개인 순 매수 위 삼성 전자',
#  '주간 추천 주 업황 개선 기대 러브콜 삼성 전자 등',
#  '삼성 분기 잠정 실적 발표 임박 코로나 수혜 이어지나',
#  '지난해 폰 위 는 화웨이 위 는 애플 삼성 위',
#  '삼성 전자 국내 최고 수준 화 력 비 스포크 인덕션 신제품 출시',
#  '숫자 로 보는 년 주식시장',
#  '돈터뷰 깡통 번 차고 비로소 습득 한 슈퍼 개미 필살기',
#  '스페셜 리포트 대기업 의 자격 현대차 글로벌 전략 디지털 역량',
#  '이재용 경 영 전념 토록 선처 청원 에 만 명 동의',
#  '만원 인덕션 벤츠 보다 비싼 초고 가 가전 초 호황',
#  '위기 때 버팀목 은 실적 장 세',
#  '메 리츠 지금 은 대세 상승 초입 년 까지 구조 적 상승 장',
#  '천 고지 앞둔 코스닥 반도체 바이오 가 견인',
#  '황소 가 된 개미 주가 시대 연 다',
#  '김기남 삼성 전자 부회장 신년사 년 은 변화 대응 하고 미래 준비 하는 원년',
#  '신년사 김기남 삼성 전자 부회장 삼성 만의 지속 가능 경영 발전 시키자',
#  '삼성 전자 업황 회복 유동성 유입 목표 가 하이',
#  '삼성 전자 실적 줄어도 목표 가 오른다 이유 는',
#  '삼성 전자 에너지 소비 효율 등급 상업 용 에어컨 확대',
#  '텔레콤 로 시작 하고 끝낸다 빅 테크 속도',
#  '늘어난 배당 성향 코스피 발판',
#  '한 달 빨라진 삼성 전자 언 팩 행사 일 요술 봉 든 괴물 폰 나온다',
#  '최고 가 랠리 삼성 전자 목표 주가 만원 나왔다',
#  '삼성 전자 를 넘어 까지 선점 시스템 반도체 조 공격 적 투자',
#  '이재용 삼성 협력 사와 손잡고 시스템 반도체 신화 쓸것',
#  '새해 재테크 전략 명의 조언 주식 비중 늘려라',
#  '사실 상 안방 인데 도 애플 에 밀려 위 씁쓸한 삼성',
#  '년 미니 시대 세진 티에스 삼성 전자 핵심 공급 업체 로 주목',
#  '신축년 대세 바로 나 컬러풀 주방 가전 쏟아진다',
#  '황소 의 해 힘찬 개장 코스피 눈앞',
#  '이재용 식 승 어부 첫 발 은 협력 사와 상생',
#  '재계 가 뛴다 소 처럼 우직하게 기업 올해 도 위기 돌파 앞장선다',
#  '고객 선택 받는건 오직 기술 경쟁력 어려워도 우수 인재 투자 계속 할 것',
#  '기업 영업 익 이상 증가 최고 갈수 도',
#  '이노 폭등 화학 삼성 최고 가 새해 랠리 첫 주자',
#  '황 성우 삼성 사장 코로나 에도 디지털 전환 은 계속 기술 활용 해 고객',
#  '삼성 전자 반도체 업황 회복 효과 목표 가 하이',
#  '최고 기술 장인 삼성 명장 명 선발',
#  '아이폰 잡으러 출격 삼성 일 갤럭시 조기 등판',
#  '스톡 톡스 코스피 분기 는 상승세 유지 반도체 자동차 주목',
#  '삼성 과 년 걸어온 협성회 매출 조 클럽 회원 사도 곳 동반 성장',
#  '인터뷰 양 향 자 중대 재해 법 산업 계 마크 도입 으로 풀자',
#  '이색 테마 적용 된 상업시설 브리티시 고덕 뛰어난 가시 성과 높은 집객 력',
#  '중국군 통제 기업 투 자금 치 조치 국내 억원 유입',
#  '스톡 톡스 개미 의 힘 이번 주 코스피 갈 수도',
#  '소 띠 해 첫 날 나타난 황소 동학 개미 가 고삐 쥐었다',
#  '스톡 톡스 긍정 재료 선 반영 펀더 멘털 괴리 유의 해야',
#  '코스피 마감 조 담은 동학 개미 덕 에 신축년 첫날 선 기염',
#  '동학 개미 덕 에 년 개장 일 코스피 상승 출발',
#  '코스피 첫 거래 일 사상 첫 선 돌파 동학 개미 의 힘',
#  '스톡 톡스 테슬라 판매 반도체 수출 호조 코스피 더 간다',
#  '이재용 놔 달라 국민 청원 에 만 여명 동의',
#  '신축년 슈퍼 사이클 에 주성 등 반도체 장비 주목',
#  '전기차 가 받치고 반도체 가 끌어 올리니 코스피 선',
#  '고지 가 보인다 코스피 상승 폭 확대 해 선 돌파',
#  '서 베이 한국 주식 은 반도체 해외 주식 은 신 재생 에 주목',
#  '서 베이 한국 주식 은 반도체 해외 주식 은 신 재생 에 주목',
#  '미니 마이크로 새해 시장 신제품 격돌',
#  '대 그룹 새해 핵심 경영 키 워드 고객 중심 사회 적 책임',
#  '차 화 전이 열 일 했다 코스피 선 주역',
#  '이재용 승 어부 첫 발 협력 사와 평택 파운드리 공장 찾아 상생 다짐',
#  '삼성 언 팩 초대장 드디어 공개 혁신 적 인 카메라 예고',
#  '삼성 새해 경영 핵심 키워 드는 고객 종합',
#  '이재용 부회장 새로운 삼성 도약 시스템 반도체 신화 만들자',
#  '삼성 최고 기술 전문가 삼성 명장 명 선정 디 플 첫 선발',
#  '통신사 랜선 시무 식 신년 화두 는 고객',
#  '지난해 스마트폰 출 하량 억 만대 돌파 애플 이 점령',
#  '오늘 의 부고 종합',
#  '코스피 시 간문제 가지 리스크 반드시 염두 에 둬라',
#  '매경 이 전하 는 세상 의 지식 매세지 월일',
#  '뇌 기억 유지 법 연구 한국 논문 네이처 에',
#  '취업 축하 땐 밝게 급전 고객 엔 안타까운 표정 사람 닮은 은행원 월 등장',
#  '이재용 더 바빠진 현 장경영',
#  '신년 기획 미래 산업 훅 들어온 시대 차세대 동력 잡아야 글로벌 리더',
#  '대형주 만 오르 네 코스피 시 총 톱 비중 육박',
#  '아이티 라떼 충전기 없애는 애플 삼 성 환경보호 냐 환경 파괴 냐',
#  '삼성 판 현대 오토 에버 될까 삼성 하루 새 급등',
#  '삼성 전자 탑재 세탁기 건조기 출품 시장 본격 공략',
#  '삼성 이 지원 한 정원석 연구 팀 자폐 치매 치료 새 전기 마련',
#  '삼성 비 스포크 시장 본격 진출',
#  '애플 배 퀄컴 배 만 전자 삼성 여전히 배고파',
#  '삼성 전자 이 그리는 빅 피처',
#  '삼성 물산 패션 부문 삼 성 전자 와 공동 마케팅',
#  '만 전자 도 부족하다 삼성 전자 목표 가 줄 상향',
#  '시가총액 조원 시대 연 삼성 전자 목표 가 만원 등장 시 총 조 의미',
#  '삼성 전자 갤럭시 캠퍼스 스토어 오픈 대학 대학원생 특별 혜택',
#  '정경 심 항소심 특검 과 설전 이재용 파기 환송 심 재판 부 에 배당',
#  '엔씨 백만 소프트 의 꿈 실현 할까 신작 모멘텀 다수',
#  '부음 소수 길씨 별세 외',
#  '갤럭시 플립 혁신 성 일본 서도 인정',
#  '정경 심 심 이재용 국정 농단 파기 환송 심 재판 부가 맡는다',
#  '김진욱 초대 공 수 처 장 후보자 재산 억 소유 부동산 은 없어',
#  '유경 좋은 생각 자산 배분 형 펀드 저 평가 담았더니 년 수익률',
#  '신년사 키 워드 로 본 신축년 기업 전략 고객 성장 우선',
#  '슈퍼 사이클 온다 증시 문 두드리는 반도체 장비 업체 들',
#  '반도체 슈퍼 사이클 다시 탄다 올해 수출 억 달러 재 돌파 종합',
#  '경영 권 불법 승계 의혹 이재용 재판 코로나 확산 에 연기',
#  '코스피 외국인 팔자 속 장 초반 보합 권 출발',
#  '코스피 조원 개인 순 매수 에 상승 반 전선',
#  '코스피 마감 올라 선대 고지 코앞',
#  '갤럭시 플립 닛 케이 선정 최우수 제품 에',
#  '올해 재계 이슈 키워 드는',
#  '삼성 지원 받는 국내 연구 팀 뇌 기억 방식 밝혀내 새 치료법 열 리나',
#  '대학생 대학원생 을 위 한 갤럭시 캠퍼스 스토어 오픈',
#  '카카오 카카오 엔터브레인 이 주도 아파트 가전 스마트 영토 확장',
#  '삼성 전자 비 스포크 돌풍 미국 서 이어 간다',
#  '삼성 전자 사업 부별 각각 적용 목표 가 만원 하나',
#  '만 전자 된 삼성 전자 시 총 도 조원 돌파',
#  '삼성 전자 밸류 에 이 션 매력 배당 확대 기 대 목표 가 하나',
#  '일주일 앞 으로 다가온 주요 대기업 중 삼성 참가 에 관심 주목',
#  '삼성 물산 패션 삼성 전자 세 일 페스 타 마케팅 진행',
#  '조 뚫은 삼성 전자 자율 주행 빅 웨이브 에 주목',
#  '삼성 전자 가전 을 나답 게 맞춘 비 스포크 만대 팔렸다',
#  '국내 농구 장악 한 세 스타 전성 시대',
#  '사상 첫 코스피 맛 만 본 동학 개미 조 넘게 샀지만 하락 마감 종합',
#  '가업승계 상속세 부터 손질 분 납기 간 공 제 대상 늘릴 듯',
#  '단독 김진욱 증여세 만원 지각 납부',
#  '매경 이 전하 는 세상 의 지식 매세지 월 일',
#  '삼성 사업 지원 감시 강화 곧 논의 이건희 차 명 재산 출연 가능성 도',
#  '전기차 한 번 충전 에 가는 전 고체 배터리 도요타 상용 화 선전포고 에',
#  '매일경제 해피 칼리지 디 브리핑 세미나 온라인 라이브 로',
#  '코스피 꿈 의 찍었다',
#  '코스피 시대 반도체 끌 고 인터넷 배터리 바이오 밀고',
#  '코로나 로 촉발 된 가전 의 진화 위생 인테리어 홈엔 터 가 키 워드 가전으',
#  '새해 에 반도체 빅사 이 클 온다 수요 느는데 재고 스마트폰 시장 회복 호',
#  '단독 특허 전문가 김창식 변호사 삼성 디스플레이 구원투수 등판',
#  '전 세계 억 명 함께한 삼성 헬스 걸음 수 도전 기능 업그레이드',
#  '만 전자 노리는 삼성 이재용 몇 백배 책임감 가져야',
#  '삼성 전자 비 스포크 누적 출 하량 만대 돌파',
#  '코스피 차지 한 삼성 전자 쏠림 벗어날 때',
#  '승현 준 삼성 리서치 소장 보다 나은 일상 의 핵심 은 최적 의 기술',
#  '코스피 시대 반도체 끌 고 인터넷 배터리 바이오 밀고',
#  '단독 이재용 삼성 부회장 수원 찾아 차세대 이동통신 사업 점검',
#  '황소 장서 나 만 소외 될라 키움 하루 신설 계좌 만 만 개',
#  '년 만에 만 원 대 삼성 백신 유통 진출 에 지배구조 기 대감',
#  '이재용 선두 기업 으로서 몇 백배 책임감 갖자 현 장경영 박차',
#  '개미 조 사자 공세 에도 코스피 보합 권선 턱밑 공 방',
#  '코스피 외인 기관 매도 에 선 하 회 보합 권 등락',
#  '코스피 마감 뚫었지만 결국 하락 선 아래 로',
#  '코로나 경제 위기 디지털 뉴딜 로 극복 조 판 깔린다 종합',
#  '교보 증권 주식 선물 하기 이벤트 만원 상당 경품 증정',
#  '주식 대 주주 요건 억 유지 년 양 도세 전면 과세',
#  '코스피 시 대한국 증시 가 달라졌어요',
#  '고지 넘을 때 마다 울 고 웃은 증시 년사',
#  '거인 서정진 셀트리온 회장 이 남긴 대 발자취',
#  '삼성 헬스 걸음 수 대결 기능 최대 명 까지 확대',
#  '신 사업 찾아보자 임 직원 명 온라인 접수',
#  '올해 디스플레이 시장 패널 활용 도 대폭 확대 기대',
#  '삼성 디스플레이 특허 급증 에 특허 관련 외부 인재 영 입',
#  '이재용 이 키운 스타트업 곳 참가',
#  '이재용 부회장 사흘 째 현장 경영 미래 기술 확보 는 생존 문제 종합',
#  '올해 스마트폰 시장 성장 삼성 위화 웨이 위',
#  '코로나 로 길어지는 집콕 쏟아지는 이색 가전',
#  '보라 빛 물결 넘실 슈퍼 줌 카메라 강조 한 갤럭시 티저',
#  '코스피 대 올라 사상 첫 돌파 선',
#  '이원욱 시행 탄소 중립 시기 앞당길 수 있어',
#  '삼 천 피 불 지른 동학 개미 사흘 간 쓸어 담은 종목 은',
#  '테스 삼 성 전자 와 억원 규모 반도체 제조 장비 계약 체결',
#  '최 경선 칼럼 유영민 비서실 장 무엇 이 다를까',
#  '디아 이 삼 성 전자 와 억 규모 반도체 검사 보드 공급 계약',
#  '코 아시아 삼성 전자 디자인 솔루션 파트너 사 긍정 적 하나',
#  '삼성 폰 기반 초등생 전용 폰 카카오 리틀 프렌즈 폰 출시',
#  '스크린 포 올 비전 제시 한 삼성 네오 세계 시장 첫 선',
#  '삼성 네오 공개 미니 전쟁 시작 됐다',
#  '특징 주 코 아시아 삼성 전자 역량 강화 에 강세',
#  '제일기획 또 일 냈다 신한 광고 천만 뷰',
#  '미리 보는 분기 어닝 시즌 코스피 안착 마중 물 될까',
#  '디즈니 애니메이션 이 치료 제 로 진화 하는 디지털 헬 스케 어 우울증',
#  '올해 키 워드 디지털 시티 로 도시 전체 가 언택트',
#  '미국 시 총 위 애플 은 얼마나 더 성장할까 자체 개발 반도체 칩 으로 애플',
#  '코 아시아 하나 텍 시스템 반도체 기술 및 사업 협력 모델 구축',
#  '전열 정비 마치 고대 그룹 오 너 주 새해 증시 이끈다',
#  '넘어선 선점 경쟁 본격 화 확장 현실 플라잉 카 일상 이 된다',
#  '라씨 로 삼성 엔씨소프트 목표 가 만원 제시',
#  '삼성 전자 달리자 하이텍 도',
#  '삼성 평택 공장 에 산업 용 가스 외국 계 점령 시장 서 토종 의 힘',
#  '진화 엄청나네 삼성 퍼스트 룩 서 최초 공개',
#  '삼성 전자 소자 크기 분 의 로 줄인 최초 공개',
#  '시 총 상위 대 기업 년새 조원 전자 주목',
#  '삼성 전자 핵심 병기 미니 베일 을 벗다',
#  '대명 아 임 레디 새해 선물 주는 대명 스마트 라이프 이벤트 진행',
#  '삼성 만 전자 이어 만 화학 눈앞 차 화전 신고 가 속출',
#  '위기 에 빛났던 코스피 신기록 쏟아내며 삼 천 피 안착',
#  '온라인 개최 앞둔 관련 주는',
#  '온라인 개최 앞둔 관련 주는',
#  '에르메스 이어 루이비통 도 새해 벽두 가격 줄 인상',
#  '포토 화상 으로 진행 되는 년 경제 계 신년인사 회',
#  '국내 모빌리티 스타트업 서 기술 력 뽐낸다',
#  '일 장 마감 후 주요 종목 뉴스',
#  '마켓 인 투자 유치한 카이 어 국내외 고객 확보 나설 것',
#  '미리 보는 이데일리 신 문 폭설 이 알려 줬다 배달 없인 못 살겠네',
#  '미리 보는 이데일리 신 문 폭설 이 알려 줬다 배달 없인 못 살겠네',
#  '금감원 이 달 삼성 증권 종합 검사 착수',
#  '설 선물 판매 개시 최고 만원 이동형 주택 도',
#  '박용만 새해 지나친 낙관 경계 년 년 내다보고 고민 해야',
#  '고지 넘긴 코스피 경험 하 지 못 한 증시',
#  '이데일리 대 한 상의 차기 회장 에 최태원 회장 단독 추대',
#  '코스피 기관 매수세에 대 상승 출발 다시 선',
#  '코스피 시대 동학 개미 내다 판 종목 은',
#  '코스피 기관 매수세에 넘게 올라선도 돌파',
#  '코스피 마감 기관 이 매수 바톤 올라 선 안착',
#  '개인 조 팔자 에도 코스피 대 올라선',
#  '대명 아 임 레디 대명 스마트 라이프 이벤트',
#  '포스트 코로나 경제 반등 다짐 경제 계 신년인사 회서 한 뜻 모아',
#  '갤럭시 일 부터 사전예약 실시 가격 은',
#  '줌 인 다음주 공개 갤럭시 모든 것 폰 주도 권 회복해라',
#  '블루 웨이브 타고 삼 천 피 안착 가고 차 화전 왔다',
#  '스톡 톡스 삼전 예상 된 실적 주가 상승세 지속',
#  '삼 성 전자 하 만 커넥티드 본격 화 디지털 콕핏 공개',
#  '삼 성 전자 하 만 커넥티드 본격 화 디지털 콕핏 공개',
#  '삼성 전자 작년 분기 영업 이익 조 전 년',
#  '코로나 에 치 이고 애플 에 밀리 고 삼성 폰 분기 는 주춤',
#  '속보 삼성 전자 분기 영업 익 조 원 컨 센',
#  '속보 삼성 전자 분기 영업 익 조 원 컨 센',
#  '코스피 마감 외인 사자 에 선 주간 상 승률 년 이후 최고',
#  '삼전 타고 삼성 그룹 펀드 도 훨훨',
#  '특징 주 외인 러브콜 에 시 총상 위주 급등 세',
#  '낡은 규 제혁 파 금산분리 원칙 에 지배구조 개편 도 시너지 창 출도 막혀',
#  '아들 아 주식 좀 알려다오 대 아버지 도 주식 삼 매경',
#  '거침 없는 코스피 오르며 선 돌파',
#  '코스피 돌아온 개인 매수세에 넘게 상승 선',
#  '엘비 세미 콘 및 매출 추가 발생 목표 가',
#  '이데일리 넥슨 김정주 가상 화폐 거래소 빗썸 인수 설 천억원 에 추진',
#  '코스피 외인 홀로 조원 넘게 사자 대 강세 에 선',
#  '코로나 확산 세 에 김재현 이병기 등 재판 일정 연기',
#  '재송일 장 마감 후 주요 종목 뉴스',
#  '삼성 전자 일 분기 경 영 실적 기 업설 명 회 개최',
#  '밑줄 쫙 동학 개미 의 활약 코스피 시대 개막',
#  '삼성 전자 지난해 영업 익 조 억 전 년',
#  '작년 월 누적 경상수지 억 달러 흑자 코로나 이전 수준 회복 종합',
#  '삼성 전자 삼성 생명 특별 계정 보통주 만주 장내 매도',
#  '파운드리 주문 에 공장 터질 판 삼성 전자 슈퍼 사이클 년 까지 간다',
#  '장 중 만원 터치 삼성 전자 작년 호실 적 발표 에 급등',
#  '삼성 전자 작년 호실 적 발표 에 만원 터치',
#  '만 전자 고 공 행진 빅데이터 도 삼 성 전자 를 찍었다',
#  '속보 삼성 전자 장 중 만원 터치 만 전자 가나',
#  '삼성 전자 지난해 영업 이익 조억원 전 년비',
#  '장 중 돌파 코스피 삼성 전자 호실 적 현대차 애플 협력 설 에 급등',
#  '코로나 위기 에 더 강해진 삼성 전자 지난해 조 벌었다',
#  '속보 삼성 전자 작년 영업 이익 조억원 전 년 대비',
#  '속보 삼성 전자 작년 분기 영업 이익 조 원 전 년 대비',
#  '속보 삼성 전자 작년 연간 매출 조억원 영업 이익 조 억 이익',
#  '장 중 만 전자 질주 증권 가 목표 주가 만원',
#  '전장 속도 내는 삼성 하 만 디지털 콕핏 공개',
#  '파죽지세 코스피 일도 폭등',
#  '삼성 전자 실적 추 정치 하 회 역기 저 환율 탓',
#  '콘서트 즐기고 영상 만들고 자동차 는 제의 생활 공간',
#  '생산 지연 호재 에 삼 성전 자 만원 찍었다 종합',
#  '삼성 전자 외인 매수 에 대 급등 세',
#  '위기 때 나온 진짜 실력 삼성 전자 작년 조 벌었다 종합',
#  '스톡 톡스 삼성 전자 분기 전 망치 하 회 환율 때문',
#  '삼성 전자 작년 분기 영업 익 조 증권 가 예 상치 미달',
#  '동학 개미 놀라워 펀드매니저 개미 생각 읽으려 유튜브 봐요',
#  '위 클리 마켓 씨앤투스 성 진솔 루 엠씨 이 랩 기업 공개 수요 예측',
#  '영진전문대 정시 모집 명 선발 년 평균 취업률',
#  '애플 자율 차 희소식 에 현대차 모비스 대 급등',
#  '분노 의 소비 덕 봤 네 가전 스마트폰 호조',
#  '안녕 인간 나 는 챗봇 이야 사회 와 거리 둔 나 와 친구 가 됐',
#  '일 개막 하는 미리 보는 관전 포인트 는',
#  '머니 주요 산업 증시 기상도 당분간 종목 장 세 다음주 개막 수 혜주 주목',
#  '최고 만 원 만전 자 삼성 의 비밀 병기 갤럭시 베일 벗는다',
#  '머니 콕 강남 큰손 들 코스피 더 오른다 분산 투자 는 어떻게',
#  '인텔 삼 성 전자 와 나노 칩 위탁 생산 협의 중 종합',
#  '유 안타 주간 추천 주 영업 익 초 강세 예상 삼 성전 자 엔씨소프트 대',
#  '유 안타 주간 추천 주 영업 익 초 강세 예상 삼 성전 자 엔씨소프트 대',
#  '하나 금투 주간 추천 주 수출 기 대감 삼 전 일진 머터 리얼 즈 케이엠 더블유',
#  '사설 코로나 여파 에도 삼성 전자 우리 경제 버팀목 확인 했다',
#  '코스닥 년 만에 등 극 할까 두 가지 빅 이벤트 촉각',
#  '장기 자의 비사 이드 전례 없는 유출 에 삼성 도 전략 수정',
#  '사이버 공간 으로 옮겨 온 미래 기술 경쟁',
#  '이 거 맞아 구부려지고 가 화질 조정 해준다',
#  '집콕 시대 대 이모 님 이 뜬다세 컨드 가전 전성 시대',
#  '돈 이 넘쳐 흐른다 코스피 과열 우려 에도 동학 개미 총알 조 육박 이번 주',
#  '마저 넘 보는 코스피 급등 세 에 우려 목소리 나오는 이유 는',
#  '삼 성 금호 석유 실적 장 세 이끌까',
#  '디지털 전환 넘어 문명 적 전환 온다',
#  '한국 개사 출동 중국 제 치고 위 참가 국 으로',
#  '경제 기지개 조선업 올해 영업 익 뛴다',
#  '삼성 전자 리모컨 에 일회용 배터리 없앤다',
#  '주간 추천 주 반도체 슈퍼 사이클 과 신 작 기 대감 삼 성전 자 엔씨소프트 등',
#  '미니 맞춤 형 가전 격돌 하 는 삼성 과',
#  '삼성 갤버프 공식 티저 언 팩 출연 도 예고',
#  '코스피 주간 외국인 순 매도 위 삼성 전자',
#  '코스피 주간 개인 순 매수 위 삼성 전자',
#  '배진솔 의 전자사전 돌 고도 는 반도체 슈퍼 사이클 그게 뭔 데 요',
#  '첫 온라인 하루 앞 으로 가전 부터 미래 기술 까지 총 출동',
#  '번가 새해 첫 월간 십 일절 권혁수 김재우 와 라이브 방송',
#  '마켓 인 세라믹 기 판 제조업체 샘 씨 엔 에스 상장 절차 본격 화',
#  '갤럭시 폴드 랜더링 등장 넓어진 외부 창 트리플 카메라',
#  '정기예금 깰래요 뭉칫 돈 증시 로 몰린다',
#  '만 전자 인텔 과 칩 동맹 성사 되나',
#  '아이티 라떼 삼성 애플 걸어야 산다',
#  '삼성 전자 태양광 리모컨 선 뵌다',
#  '삼 성 전자 에 빠진 동학 개미 개인 비중 기관 제 쳤다',
#  '주 간증 시 전망 단번 에 선동 학 개미 고소공포증 이겨내나',
#  '강창진 세메스 대표 년 세계 톱 반도체 장비 될 것',
#  '작은 버튼 하나로 코로나 진단 홀로그램 으로 회의 생중계 까지',
#  '로봇 앞세운 삼성 롤러 블 폰 기 대감 키운',
#  '청소 부터 식탁 세 팅 정리 까지 눈길 사로잡은 삼성 로봇',
#  '중대 재해 법 졸 속 입법 논란 여야 합의 통과 에도 불씨 여전',
#  '운용 수소 경제 순 자산 합계 억 돌파',
#  '기자 수첩 마이 데이터 제동 걸리게 된 네이버 의 한숨 혁신 은 어디 로',
#  '나 만 소외 될 수 없다 코스피 서 개미 조원 넘게 주식 쇼핑',
#  '코스피 거래 대금 조 원로 역대 최고 치 동학 개미 파워',
#  '키움 증권 하루 만 계좌 개설 최대 기록 개인 조 순 매 수의 힘',
#  '어닝 시즌 실적 컨센서스 와 주가 상관관계 는',
#  '코스피 개인 매수세에 가까이 상승',
#  '주식 쓸어 담는 개미 코스피 장 중 선 터치',
#  '기관 외국인 매도 공세 에 코스피 선 까지 후퇴',
#  '코스피 마감 개인 역대 급 매수 에도 외인 기관 맞 불 에 약 보합',
#  '수출 실적 눈높이 너무 높았나 삼천 피 흔들까 우려',
#  '코스피 자 상승 대형주 만 사고 대형주 만 오른다',
#  '이데일리 세계 최대 전자 전시회 온라인 개막',
#  '삼성 은 석 학 는 가상 인간 연사 가 사람 다운 일상 을 만듭 니',
#  '이재용 삼성 준법 감 시위 독립 활동 보장 뉴 삼성 준법 의지 강조',
#  '최후 진술 약속 지킨 이재용 삼성 준법 감 시위 면담 정례 화',
#  '삼성 전자 올해 이익 증가 율 극 대화 목표 가 미래에셋',
#  '특징 주 삼 성 전자 장 초 부터 만원 돌파 하며 강세',
#  '중소기업 은 없다',
#  '주식 조 쇼핑 한 동학 개미 삼성 전자 쓸어 담았다',
#  '만 전자 삼성 요리 청소 반려동물 도우미 로봇 내놨다',
#  '이 젠 만 전자 로 불러다오 삼성 전자 이틀 째 장 중 최고 가',
#  '돈 많은 동학 개미 가 삼 성 전자 로 몰려 간 까닭',
#  '만 전자 안착 삼성 전자 대 급등 하며 사상 최고 가 갱신',
#  '이재용 삼성 전자 부회장 삼성 준법 감 시위 독립 활동 보장',
#  '속보 삼성 전자 급 등장 중 만원 넘어',
#  '삼성 전자 성장 본격 화 파운드리 성장 모멘텀 목표 가',
#  '애 봐주고 업무 관리 나 만의 비서 나온다',
#  '단독 한국 만 세금 역주행 법인세 부담 년새 조원 늘었다',
#  '애플 과 손 잡는다고 현대차 시 총 위로 점프',
#  '애플 과 손 잡는다고 현대차 시 총 위로 점프',
#  '동학 개미 분만 에 조원 순 매 수 코스피 장 중 선 돌파 종합',
#  '삼성 은 석 학 는 가상 인간',
#  '주식 조 쇼핑 한 동학 개미 삼성 전자 쓸어 담았다',
#  '삼성 전자 해외 기업 비해 여전히 저 평가 목표 가유 안타',
#  '미시간 대 자랑스러운 동 문상 루크 강전 경 훈 정재호 씨 선정',
#  '개미 순 매수 조 육박 널 뛰는 코스피 폭등 후 급락',
#  '동학 개미 조원 매수 에도 외국인 기관 매도 폭탄 에 코스피 하락',
#  '삼성 테슬라 손잡고 위 굳힌다',
#  '삼성 프리미엄 모바일 기기 엑시노스 출시 최적화 이뤄',
#  '디오스 텍 억원 제자 배정 유상증자 납입 최대 주주 변경',
#  '코스피 개인 기관 외인 맞 불 보합 권 등락',
#  '불 장 뛰어드는 불개미 쩐 의 이동 거세진다',
#  '코스피 개인 조 순 매수 에도 선 까지 후퇴',
#  '코스피 외국인 매 도세 에 하락 출발 선 열기 식히나',
#  '코스피 마감 기관 외인 동반 매도 에 하락 동학 개미 선 사수',
#  '자 이 앤트 레터 전기 대 격돌 화학 손잡고 테슬라 이길 것',
#  '코스피 과열 잇단 경 고 동학 개미 는 그래도 산다',
#  '푸드 테크 메디 프레 소 에서 한 방 티 캡슐 세계 에 알린다',
#  '양 향 자 동학 개미 삼전 투자 는 애국 공매도 금지 연장 해야',
#  '제일기획 이노 텍 삼성 물산 증시 숨고를 때 주목 해야 하는 종목 은',
#  '개미 이틀 새 조 기록 적 매 수삼 성 셀트리온 은 버텼다',
#  '포토 혁신 상 삼성 비 스포크 정수기 분기 출시',
#  '삼성 갤 두뇌 나왔다 모바일 엑시노스',
#  '삼성 출시 제품 직접 보니홈트 트레이너 가 속 으로',
#  '삼 성 전자 셀트리온 삼바 공매도 대 기물 량 조 단기 조정 우려 전문가 전망',
#  '코스피 개인 외국인 기관 공방전 삼성 전자 현대차 도 주춤',
#  '디오스 텍 억원 제자 배정 유상증자 납입 최대 주주 변경',
#  '박성식 제주 반도체 대표 주문 량 밀려 들어 이미 풀캐파',
#  '첨단 안과 검사 혁신 뽐내는 스타트업',
#  '박영선 장관 코로나 백신 주사기 월 말 양산',
#  '코로나 가 앞당긴 미래 기술 삼성 신제품 주목',
#  '자동 살균 에 모듈 추가 까지 삼성 비 스포크 정수기 공개',
#  '집콕 수요 겨냥 삼성 정수기 모니터 종 출시',
#  '삼성 인텔 첨단 기술 력 앞세운 반도체 신제품 공개',
#  '지금 까지 이런 화질 은 없었다 삼성 네오 첫 공개',
#  '펫 케어 하고 동반 자도 돼주는 삼성 로봇 공학 의 가까운 미래',
#  '이번 엔 롤러 블폰 대결 전자',
#  '삼성 언 팩 공식 예고편 공개 갤럭시 총사 데뷔',
#  '디바이스 이 엔 지 삼 성 중국 반도체 와 억원 규모 공급 계약',
#  '파버나 인 미니 무인 단말기 성장 수혜 리서치 알음',
#  '삼성 전자 올해 영업 익 조 전망 목표 가 현대차',
#  '삼성 전자 쏠림에 기죽은 중소 형 펀드 수익률',
#  '코스닥 공시 디바이스 이 엔 지',
#  '김종인 윤석열 지금 별 보일 것 후보 될수도',
#  '미리 보는 이데일리 신문 강남 재건축 안 풀 면 서울 주택 난 못 푼다',
#  '한중일 경 영자 들 이 가장 주목 하는 한국 는 누구',
#  '삼성 전자 취향 따라 필요 기능 고르는 비 스포크 정수기 출시',
#  '코스피 고 점 확인 까지 잔고 감소 지속 될 것유 안타',
#  '베일 벗은 롤러 블폰 뜯어 보니 적자 탈출 승부 수',
#  '엠씨 넥스 참가 측면 사물 인지 자율 주행 카메라 시스템 선보여',
#  '파리 날리는 세계 최대 바이오 행사 이 게 다 대형주 때문',
#  '출사표 솔 루엠 성장하는 전자부품 업체 년내 위 달성',
#  '인텔 에 위탁 생산 고려 엔비디아 삼성 에 맞 불',
#  '말 랑 리뷰 반려견 대변 도 인식 삼성 제트 봇 살펴보니 영상',
#  '빅 테크 기업 들 윤리 규범 두고 있나 카카오 가 최초',
#  '스마트 개미 덜 오른 종목 에 돋보기',
#  '코스피 마감 개인 외인 동반 매수 에 선 다지기',
#  '코스피 개인 기관 동반 매수세에 상승 출발 선',
#  '전 에 없던 대형주 월 효과 우선주 로 잡아 볼까',
#  '지상파 중간광고 년 만에 허용 규제 혁신 타 매체 광고 억 이동',
#  '국내 중소 벤처기업 개사 혁신 상 수상',
#  '코스피 개인 기관 외인 맞 불 지 속 보합 권 등락',
#  '이익공유제 추진 정치권 들썩 기업 들 한숨',
#  '공매도 영구 금지 청원 만 명 돌파 공매도 가 뭐길 래',
#  '코로나 항체 치료 제 기대 셀트리온 베팅 하는 개 인들',
#  '주 연속 상승 코스피 조정 불가피 까지 열어 둬야',
#  '한국판 파브르 한국인 최초 사무 총장 등 과학계 거목 영상 으로',
#  '안건 준 벤 처 협회장 올해 원 격의 료 데이터 규제 완화 에 집중',
#  '줌 인 유튜브 서 먹방 쿡방 소통 의 신세계 연 로그 정용진',
#  '한국판 파브르 한국인 최초 사무 총장 등 과학계 거목 영상 으로',
#  '삼성 월 첫 주 신규 고객 만 명 지난해 월 전체 배',
#  '혁신 상 받은 스마트폰 개중 개 가 삼 성 이유 는',
#  '삼성 전자 모두 를 위 한 더 나은 일상 만 뷰 돌파',
#  '삼 성 전기 서 분사 한 솔루엠 세 계위 전자부품 코스피 노크',
#  '삼성 전자 갤럭시 가격 확정 이번 에는 얼마 에 나올까',
#  '서버 클라우드 칩 수요 폭발 역대 급 합종연횡 펼쳐진다',
#  '왜 내 주식 만 코스피 폭등 인데 동료 중 에 돈 번 사람 없는 이유',
#  '삼 천 피 등 정서 소외 됐던 대형 제약 호실 적 기대 로 다시 주목 받나',
#  '연말정산 일 시작 개 민간인 증서 어떤게 좋을까',
#  '테라 사이언스 디스플레이 강소 기업 씨엘 에 스코리아 인수',
#  '증시 숨고를 때 도 곱 버스 는 곤두박질 장기 투자 금물',
#  '영진전문대 최근 년 평균 취업률 넘어 해외 취업 년 연속 전국 위',
#  '피플 필수 된 클라우드 공공 부문 디지털 전환 앞당길것',
#  '주일 새 까먹었다주가 천시 대 곡 소 리나 는 곱 버스 투자자',
#  '현대차 연내 아이폰 으로도 시동 켠다',
#  '이 젠 유튜브 서 활개 치는 주식 리딩 방 사기피해 급증 주의보',
#  '대 기업 매출 조 벽 깼다 삼 성전 자 년 째 매출 왕좌',
#  '삼성 전자 만 전자 만 전자 갈림길',
#  '개미 조 베팅 삼성 전자 만 전자 갈까',
#  '만원 짜리 플래그 십 삼성 의 가격 승부 수 통 할까',
#  '안건 준 벤 처 협회장 올해 원 격의 료 데이터 규제 완화 에 집중',
#  '국내 제조 혁신 스마트 공장 만 개 구축 달성',
#  '갤러리아 광교 새해 첫 고객 맞이 행사',
#  '아이티 라떼 노 태문 사장 기 고문 으로 미리 본 올해 갤럭시 언 팩',
#  '위기 의 인텔 기간 중 교체 엔지니어 출신 이 구원투수 로',
#  '갤럭시 전작 보다 잘 팔릴 것 갤 대비 예상',
#  '경자년 우울했던 통신 장비 신축년 새해 훨훨',
#  '폐막 앞둔 기업 별 성적표 는',
#  '삼성 에 밀렸다 위기 의 인텔 문책 성 교체 종합',
#  '삼성 전자 라는데 올해 파운드리 에 투자',
#  '삼성 디스플레이 노사 단협 체결 삼성 무 노조 폐기 첫 성과',
#  '삼성 전자 세 일 페스 타 풍 성한 혜택 제공',
#  '코로나 이익공유제 추진 에 재계 당혹 혼란 만 야기 해',
#  '외국인 연초 코스닥 천억 팔 아 치웠지만이 종목 은 담았다',
#  '년전 테슬라 추천 했던 박현주 그 가 꼽 은 개 성장 산업 은',
#  '공 천 개입 까지 년 사면 가석방 없으면 세 출소',
#  '자 이 앤트 레터 시그널 반다이 머스크 트윗 하나 에 울 고 웃는 글로벌 주식 들',
#  '수익률 문재인 펀드 어디 투자 했나 봤더니',
#  '만원 갤럭시 아이폰 와 진검 승부 애플 떨고 있나',
#  '달군 디스플레이 실물 서울 에 뜨니 들 놀랍다',
#  '가 인지 노동 대체 생산 성 빅뱅 온다',
#  '삼성 디스플레이 노사 합 의무 노조 경영 폐기 후 첫 성과',
#  '새해 첫 대규모 가전 축제 삼성 전자 세 일 페스 타 인기 고공 행진',
#  '코스피 기관 외국인 동반 매 도세 에 하락 출발 선',
#  '현 대판 연좌제 주식양도세 가족 합산 폐지 해야',
#  '코스피 마감 파월 의 입 주시 하며 관망 강 보합',
#  '태블릿 부터 징역 년 확정 까지 박근혜 의 일',
#  '박현주 미래에셋 회장 테슬라 주가 정당하다 혁신 이 중요',
#  '박영수 특검 국정 농단 뇌물 공 여자도 합당 한 판결 선고 기대',
#  '한국 투자 증권 종목 신규 상장',
#  '국정 농단 박근혜 징역 년 확정 사면 논의 본격 화 전망',
#  '실리콘 마이 터스 창업 자 허 염 사장 회장 승진',
#  '실리콘 마이 터스 창업 자 허 염 사장 회장 승진',
#  '반도체 리더십 잃었다 인텔 경질 성 교체',
#  '미리 보는 이데일리 신문동 상 이몽 공매도 은 성수 소신 지키나',
#  '삼성 개 개 혁신 상 휩쓸어',
#  '코스피 외국인 기관 매 도세 에 하락 전환 선 위협',
#  '디아 이 억 규모 반도체 검사 장비 공급 계약',
#  '텔레콤 갤럭시 예약판매 싼 온라인 요 금제 가능',
#  '마켓 컬리 보냉 포장 박스 세계 월드 스타 패키징 어워드 수상',
#  '포토 갤럭시 카메라 기능 강화',
#  '포토 일 공식 출시 하는 갤럭시',
#  '포토 갤럭시 로 출시',
#  '포토 베일 벗은 갤럭시',
#  '임 대기 전 삼성 라이온즈 대표이사 대 한 육상 연맹 회장 당선',
#  '이재용 선처 해달라 박용만 법원 에 탄원서 제출',
#  '삼성 전자 아우디 와 손잡았다 신형 갤럭시 로 디지털 키 기능 제',
#  '삼성 전자 글로벌 언 팩 행사 펜 품은 갤럭시 공개',
#  '갤럭시 출격 통신사 지 원금 최고 만원',
#  '힘 부치는 황소 개미 코스피 급락',
#  '갤럭시 올해 판매량 만만 대 추정',
#  '코스피 마감 동학 개미 조 실탄 에도 선 붕괴',
#  '겉 도 속도 다 바꿨다 갤럭시 버즈 프로 애플 에어팟 넘어설까',
#  '갤럭시 시리즈 오늘 부터 사전예약 다양한 혜택 제공',
#  '머니 주요 산업 증시 기상도 동학 개미 추격 매수 과열 조짐 월 공매도 재개',
#  '사전예약 돌입 한 갤럭시 공 시 지 원금 어디가 많이 주 나',
#  '모빌리티 로봇 물밀듯이 쏟아진 생활 속 혁신',
#  '반도체 품귀 포드 생산 중단 주 문 폭주 로 즐거운 비명',
#  '박용만 회장 이재용 선처 해달라 법원 에 탄원서',
#  '코스닥 공시 노바 렉스 디바이스 이 엔 지 디아 이',
#  '빚투 목 까지 차올랐다 증권사 신용 대출 잇따라 중단',
#  '임 대기 삼성 라이온즈 대표 대 대 한 육상 연맹 회장 당선',
#  '세대 부터 까지 공략 롯데 현대 도 복합 쇼핑몰 출격',
#  '사설 이 보여준 일상 의 혁신 주역',
#  '이주열 경기 개선 확신 못 하는데주가 상승 너무 빨라',
#  '부캐 로 소통 하는 세상 그 곳 에 미래 고객 이 있다',
#  '이건 미리 사야 돼 이커머스 업체 들 갤럭시 사전 예약판매 돌입',
#  '삼성 개 개 상 휩쓴 기업 들 종합',
#  '언 팩 삼성 플래그 십 폰 의 새로운 기준 제시',
#  '메모리 최첨단 기술 전면 에 삼성 반도체 초 격차 확대',
#  '더욱 풍부한 색 삼성 억만 화소 이미지 센서 아이 소 셀 출시',
#  '삼성 개 개 상 휩쓴 기업 들 종합',
#  '동학 개미 코스피 조 베팅 절반 이 삼 성 전자 로',
#  '언 팩 삼 성 전자 야심작 엑시노스 시장 서 흥행 자신감',
#  '삼성 전자 올해 시장 트렌드 미니 집콕 친환경',
#  '삼성 전자 어워드 싹 쓸이 글로벌 미디어 호평 쏟아져',
#  '삼성 전자 강력 세탁 그 랑 데 통 버블 전 자동 세탁기 출시',
#  '하이 투자 증권 한국판 뉴딜정책 엔 코리아 뉴딜 펀드 추천',
#  '제일기획 제작 참여 삼성 영상 만 뷰 넘었다',
#  '코스피 넘어 순항 기 대감 코스피 상승 장 언제 까지',
#  '올 대 트렌드 는 미니 스마트 기능 친환경',
#  '올 대 트렌드 는 미니 스마트 기능 친환경',
#  '더욱 풍부한 색 삼성 억만 화소 이미지 센서 아이 소 셀 출시',
#  '언 팩 갤럭시 를 똑똑하게 쓰는 법 스마트 씽 스 태그 강조',
#  '갤럭시 시리즈 출 하량 전작 보단 시리즈 평균',
#  '메모리 반도체 부족해진다 국내 기업 기술 격차 치고 나가야',
#  '갤럭시 시리즈 출 하량 만대 전망 전작',
#  '코스피 바이든 추가 부양책 기 대감 에 상승 출발 선',
#  '베일 벗은 갤럭시 가격 낮추고 성능 높였다',
#  '싼 온라인 요 금제 보이는 컬러링 최대 만원',
#  '언 팩 점유 율 만회 주도 권 두 토끼 사냥 나선다',
#  '사상 첫 사이버 공간 서 펼쳐진 미래 기술 경쟁',
#  '언 팩 갓 성비 무선 이어폰 등 극 하나 갤럭시 버즈 프로 출격',
#  '언 팩 얼굴 은 완전히 다른데 아이폰 기능 품은 갤럭시',
#  '메모리 슈퍼 사이클 온다 반도체 퀀텀 점프 부푼 꿈',
#  '메모 리더 높이 쌓아라 치열해지는 낸드 플래시 적층 경쟁',
#  '코스피 개인 조 매수세에도 한때 선 밑 돌아',
#  '갤럭시 이른 출시 수혜 기대 되는 부품 업체 는',
#  '갤럭시 공개 에 외신 가장 주목 할 점 은 가격',
#  '번가 삼성 갤럭시 시리즈 라이브 방송 으로 사전 예약',
#  '포토 갤럭시 삼성 의 폰 승부 수',
#  '이재용 선처 탄원서 낸 박용만 삼성 무게 감 생각 해달라 종합',
#  '말 랑 리뷰 삼성 갤럭시 만져 보니 큰 변화 는 없네 영상',
#  '디아 이 삼 성 전자 에 억 규모 반도체 검사 장비 공급',
#  '디바이스 이 엔 지 삼 성 전자 와 억원 규모 반도체 공급 계약',
#  '디바이스 이 엔 지 삼 성 전자 와 억원 규모 반도체 공급 계약',
#  '샤오미 도 제재 대상 포함 삼 성 전자 와 국내 부품 사 수혜',
#  '삼성 전자 갤럭시 배경 인물 제거 기능 추가',
#  '언 팩 이건 몰랐지 삼성 언 팩 서 펜 프로 공개',
#  '언 팩 삼성 플래그 십 폰 의 새로운 기준 제시',
#  '메모리 최첨단 기술 전면 에 삼성 반도체 초 격차 확대',
#  '유플러스 갤럭시 사전예약 지 원금 최대 만원',
#  '만 전자 이끌 삼성 의 비밀 병기 만원 대 폰 내놨다',
#  '갤럭시 사전예약 보이는 컬러링 전용 보험 최대 만원 보상',
#  '갤 싸게 사는 법 만원 지 원금 요금 인하',
#  '밑줄 쫙 박근혜 징역 년 확정 사면 논의 재 점화',
#  '머 하 회 이 말 올이 먼말 주린이도 고수 도 북적 북적',
#  '배진솔 의 전자사전 삼성 스마트폰 두뇌 눈 출시 시스템 반도체 포섭 신',
#  '말 랑 리뷰 삼성 갤럭시 울트라 써 보니 카메라 가 선 넘네 영상',
#  '써 보니 갤럭시 울트라 극 강 화면 에 펜 쓰는 재미 도 쏠쏠',
#  '어 애니콜 이네 이건희 폰 갤 버즈 프로 케이스 화제',
#  '금나와라 뚝딱 개미 주머니 서 나온 일 에 무슨 일이',
#  '유플 만큼 도 만원 까지 지원 갤 만원 대면 산다',
#  '말 랑 리뷰 삼성 갤럭시 울트라 써 보니 카메라 가 선 넘네 영상',
#  '대통령 소 부장 이어 뉴딜 펀드 투자 방향성 알려주나',
#  '갤럭시 울트라 카메라 미터 거리 같은 곳 찍어 봤더니',
#  '단독 모바일 반도체 주문 너무 몰려요 삼성 전자 공급 비상',
#  '폰 보러 갔다가 갤럭시 버즈 프로 매력 에 빠졌다',
#  '코로나 년언택트 일상 화 생계 위협 코로나 형 범죄',
#  '전경련 이익공유제 기업 혁신 과 성장 유인 약화',
#  '코로나 위기 속 커지는 역할 론 각계 선처 호소 잇따라',
#  '이재용 재판 에 쏠린 눈일 선고 집행유예 나올까',
#  '갤럭시 울트라 카메라 미터 거리 같은 곳 찍어 봤더니',
#  '노 태문 사장 이 밝히는 갤럭시 에 펜 을 적용 한 진짜 이유',
#  '코스피 주간 개인 순 매수 위 삼성 전자',
#  '써 보니 전격 비교 갤럭시 일반 울트라 급 나누기 맞긴한데',
#  '코스피 주간 기관 순 매도 위 삼성 전자',
#  '집행유예 냐 실형 이냐 이재용 파기 환송 심 형량 가를 쟁점 은',
#  '슈퍼 개미 이정윤 배터리 투자 안 늦었다',
#  '전문가 코스피 이 젠 외국인 을 봐라',
#  '이재용 운명 의 날 법원 준법 경영 성과 고려 할까',
#  '독일 사 칩 공급 해달라 대 만 정부 에',
#  '이재용 내일 운명 의 날 중소기업 도 선처 요청 나섰다',
#  '파운드리 대란 에 대만 조 폭풍 투자 한국 은 허송 세월',
#  '코로나 년 위기 를 기회 로 전자 업계 펜트업 수요 에 실적 하이킥',
#  '이재용 운명 의 날기 로 에 놓인 뉴 삼성',
#  '중소기업 계 사법부 이재용 부회장 선처 해야 호소',
#  '말 랑 리뷰 갤럭시 개체 지우기 기능 써 보니 포토샵 이 필요 없네 영',
#  '갤럭시 직접 체험 해 보세요 최대 일 무료 대여',
#  '폰 보러 갔다가 버즈 프로 매력 에 빠졌다',
#  '재벌 아이템 전 성 시 대 정용진 이 픽하 면 왜 뜰까',
#  '천안 아산 아파트 브랜드 효과 톡톡 집값 억대 격차',
#  '이재용 실형 선고 법정구속 시킨 정준영 부장 판사 는 누구',
#  '분양 하이라이트 브리티시 고덕 고덕 국제 신도시 영국 풍 의 스트리트 몰',
#  '필동 정담 벼락 거지',
#  '유재석 갤럭시 캠페인 서 펭수 와 유쾌한 재회',
#  '이재용 실형 선고 에 탄식 법정 곳곳 서 울음소리 도',
#  '미래 컴퍼니 업계 최초 전용 칩 출시',
#  '선고 직후 이재용 드릴 말씀 없다 고개 숙여',
#  '달러 강세 구속 에 삼 성전 자 시 총 하루 만에 조원 증발',
#  '혁신 경쟁 치열한데 리더십 공백 에 세계 등 삼 성 폰 도 우려',
#  '포토 이재용 삼성 전자 부회장 파기 환송 심 에서 법정구속',
#  '특징 주 이재용 법정구속 에 삼 성 전자 호텔 신라',
#  '포토 법정 향 하는 황성수 전 삼성 전자 전무',
#  '포토 법정 도착 한 황성수 전 삼성 전자 전무',
#  '포토 이재용 삼성 전자 부회장 묵묵 부답',
#  '포토 법정 도착 한 이재용 삼성 전자 부회장',
#  '국정 농단 명중 명 재판 마무리',
#  '반려견 자동 차키 분실 걱정 끝 삼성 스마트 태그 출시',
#  '구치소 로 이동 한 이재용 구심 점 잃은 삼성 참담한 분위기',
#  '이재용 구속 에 당혹스러운 삼성 년 만에 다시 비상 경영 체제 돌입',
#  '포토 국정 농단 사건 파기 환송 심 선고 공판 향 하는 박상진 전 삼성 전자 사장',
#  '개미 총알 아직도 조 증권사 가 추천 하는 분산 투자 상품',
#  '이재용 실형 전경련 경 총 한국 경제 악 영향 우려',
#  '특검 도 변호인 도 재상 고 여지 남겨',
#  '전자 물산 삼성 그룹 시 총 조 증발',
#  '믿었던 삼성 전자 현대차 급락 에 쩐 의 전쟁 동학 개미 울상',
#  '패닉 빠진 삼성 투자 중단 위기 성장 시계 멈출 듯',
#  '재계 삼성 판결 경제 악 영향 중 소 협력 사 연쇄 충격 우려',
#  '생존 경쟁 거 센데 총수 부재 삼성 시계 제로',
#  '생존 경쟁 거 센데 총수 부재 삼성 시계 제로',
#  '구속 된 날 삼성 그룹 주 시 총 조 증발 이전 구속 기간 보니',
#  '언론 삼성 또다시 톱 부재 비상 사태 외신 도 긴급 타전',
#  '삼성 또다시 시계 제로 세계 위 반도체 비전 차질 빚 나',
#  '이재용 부회장 실형 선고 에 삼성 그룹 우수수',
#  '포토 이재용 부회장 징역 년 개 월 선고',
#  '이재용 징역 년 개월 실형 법정구속 또 위기 맞은 삼성 종합',
#  '만 전자 도 위태 올해 만 조 산 동학 개미 어쩌나',
#  '반려견 사라져도 쉽게 찾는다 삼성 갤럭시 스마트 태그 출시',
#  '지배구조 개편 물건 너 가회 장 취임 도 사실 상 무산',
#  '삼성 준법 위도 못 구한 이재용 사면 가능성 은',
#  '시노펙 스 갤럭시 출시 기념 마스크 할인 행사',
#  '이재용 운명 의 날 집행유예 냐 실형 이냐 갈림길',
#  '준법 위 제안 한 정준영 판사 실효 성 없다며 구속',
#  '이재용 파기 환송 심 징역 년 개월 법정구속 종합',
#  '예 상치 못 한 구속 에 준법 감 시위 활동 찬물',
#  '메이드 인 베트남 현대차 꺾고 전기차 시장 도전',
#  '닛 케이 삼성 또다시 톱 부재 의 비상 사태',
#  '이재용 구속 에 화들짝 삼 성 그룹 시 총 조 증발',
#  '포토 국정 농단 사건 파기 환송 심 선고 공판 향 하는 이재용 삼성 전자 부회장',
#  '포토 법정 향 하 는 최지성 전 삼성 미래 전략 실장',
#  '무역 협회 경제 중심 역할 이재용 부회장 구속 결정 안타깝다',
#  '이재용 년 개 월 실형 변호인 단 기업 자유 와 재산권 침해 된 사건',
#  '이재용 법정구속 에 민주당 통렬 한 자기 반성 정의당 참회 부족함 없어야',
#  '전경련 이재용 실형 매우 안타깝다 경제 악 영향 우려',
#  '선고 앞둔 이재용 부회장 묵묵 부답으로 법정 향 해',
#  '이재용 오늘 운명 의 날실 형 집행유예 갈림길',
#  '뉴스 새벽 배송 대통령 신년 기자회견 공매도 언급 할까',
#  '바른 사회 이재용 부회장 유죄 판결 법치 주의 무너졌다',
#  '국민의당 이재용 구속 판결 에 법원 판단 과 양형 존중',
#  '경제 어려운데 중소 중견 기업 계 이재용 구속 우려',
#  '경 총 삼성 경영 공백 경 제 산업 에 악 영향 불가피',
#  '더 큰 바보 이론 떠오르게 하는 증시 인플레 주목',
#  '이재용 법정구속 에 새로운 시작 환골탈태 주문',
#  '퇴근길 뉴스 이재용 징역 년 개 월 실형 법정구속',
#  '기관 외국인 처럼 공매도 수수료 담보 율 개미 에게도 비슷하게',
#  '포토 국정 농단 사건 파기 환송 심 선고 공판 향 하는 이재용 부회장',
#  '박영수 특검 이재용 실형 에 대법 판결 취지 감안 한 선고',
#  '건설 올해 만여 가구 공급 예정',
#  '포토 법정 향 하는 이재용 부회장',
#  '박영수 특검 이재용 실형 에 대법 판결 취지 감안 한 선고',
#  '건설 올해 만여 가구 공급 예정',
#  '포토 법정 향 하는 이재용 부회장',
#  '박영수 특검 이재용 실형 에 대법 판결 취지 감안 한 선고',
#  '건설 올해 만여 가구 공급 예정',
#  '하이닉스 등 소비자 용 국내 첫 출시',
#  '포토 이재용 부회장 운명 의 날집 유실 형 갈림길',
#  '포토 이재용 부회장 운명 의 날',
#  '포토 법정 향 하는 최지성 부회장',
#  '한국 경제 에 악 영향 불가피 이재용 사면 요구 거세진다',
#  '코로나 년 빨라진 디지털 전환 달라진 시 총 지도',
#  '리스크 유형 화 컨트롤 타워 감시 부족 이재용 못 구한 준법 위',
#  '준법 감시 위도 재계 선처 도 안 통 했다 이재용 년 만에 재구 속 종합',
#  '포토 장충 기 전 삼성 미래 전략 실 사장 징역 년 개월 실형 선고',
#  '삼성 정치권 력 바뀔 때 마다 범죄 연루 이재용 법정구속 상보',
#  '삼성 준법 감 시위 재판 결과 상관없이 역할 소임 다 할 것',
#  '삼성 준법 감 시위 재판 결과 상관없이 역할 소임 다 할 것',
#  '구속 에 잃어버린 년 현실 화 된 삼성',
#  '한국 경제 에 악 영향 불가피 이재용 구속 에 삼성 참담 재계 충격',
#  '속보 삼성 준법 감 시위 실효 성 충족 했다고 보기 어려워',
#  '속보 삼성 준감위 양형 반영 부적절 실형 불가피',
#  '삼성 전자 투고 서비스 인기 갤 재고 없어요',
#  '테스 삼 성 전자 에 억원 규모 반도체 제조 장비 공급',
#  '단독 삼성 자회사 하만 디지털 믹싱 기업 스튜 더 매 각 선택 과 집중',
#  '삼성 디스플레이 노조 변화 선택 한 삼성 노사 문화 긍정 적 신호',
#  '포토 차 에서 내리는 최지성 전 삼성 미래 전략 실장',
#  '코스피 마감 기관 매도 에 선도 붕괴 삼전 급락',
#  '삼성 물산 삼성 그룹 지배 주주 승계 이슈 마무리 국면 목표 가신 한',
#  '갤럭시 울트라 테스트 사용자 심각한 발열 현상 나타나',
#  '개인 쌍끌이 매도 코스피 대 하락 출발',
#  '포토 국정 농단 이재용 파기 환송 심 에서 법정구속',
#  '대 한 상의 경제 중요 지점 서 이재용 구 속 경제 계 대응 차질 우려',
#  '포토 법정 향 하는 이재용 최지성 장충 기 박상진 황성수',
#  '개미 사니 기관 이 매도 코스피 대 하락 중 선',
#  '접는 폰 전쟁 에 애플 도 참전 폴 더블 아이폰 나온다',
#  '만원 공 시 지 원금 자 급제 폰 갤 어떻게 사면 이득',
#  '최대 기업 리더십 공백 이재용 구속 에 외신 긴급 타전',
#  '경제 악 영향 불가피 경제 계 이재용 구속 에 깊은 우려 종합',
#  '상장 협 이재용 유죄 선고 경제 악 영향 우려',
#  '이낙연 이익공유제 통 할까 김세형 칼럼',
#  '암참 회장 이재용 구속 에 과도 한 형사 책임 묻는 사례',
#  '하나 금융투자 하나 고 배당 금융 테크 랩 전기차 성 장주 담고고 배당',
#  '제임스 김 암참 회장 실망 스러운 이재용 구속 한국 만의 특수 문화',
#  '좋은 지배구조 펀드 지배구조 투명 기업 투자수익률',
#  '이재용 코로나 음성 주 격리 후 독방 서 지낼 듯',
#  '매경 이 전하 는 세상 의 지식 매세지 월 일',
#  '하이 투자 증권 코리아 뉴딜 펀드 주식 형 뉴딜 디지털 친환경 투자 개',
#  '이재용 부회장 사면 해달라 청원 잇따라',
#  '구속 에 삼성 전자 주가 실적 악 영향 과거 흐름 보니',
#  '충남도 올해 첫 억 외자 유치 일본 다 이 킨 공업 당진 에 새 공장',
#  '하이닉스 를 보면 반도체 투자 시기 가 보인다',
#  '삼성 이 전문가 명 투입 백 신 주사기 생산 성 배',
#  '돌아온 기관 외국인 코스피 급 반등',
#  '돌아온 기관 외국인 코스피 급 반등',
#  '실적 뒷받침 된 증시 조정 기간 길지 않을것 자이앤트',
#  '포토 이재용 법정 구속 으로 삼성 비상 경영 불가피',
#  '삼성 청년 아카데미 입학식',
#  '반도체 품귀 는 기회 삼성 이미지 센서 선점 나섰다',
#  '이재용 임원 접견 도 막혀 삼성 주간 경영 진공상태',
#  '사설 글로벌 기술 전쟁 한창 인데 다시 리더십 위기 빠진 삼성 전자',
#  '이재용 구속 이후 삼성 전자 주가 의 향방 은 핫이슈',
#  '일시 적 기우였나 충격 의 삼성 전자 반등',
#  '개미 등 돌리고 외국인 기관 은 줍 줍 삼 성 전자 거래 일 만에 상승 전환',
#  '국민 된 삼성 전자 아파트 벽 에 붙은 이재용 구속 반대',
#  '하이닉스 를 보면 반도체 투자 시기 가 보인다',
#  '삼성 전자 지원 으로 풍림파마텍 백신 주사기 월 만 개 양산',
#  '중 기부 삼성 전자 지원 받은 풍림파마텍 코로나 백신 주사기 월 만 개 생산',
#  '이재용 부회장 법정구속 삼성 전자 주가 향방 은',
#  '이재용 뇌물 공 여 유죄 불법 경영 권 승계 재판 에 불리할까',
#  '이재용 뇌물 공 여 유죄 불법 경영 권 승계 재판 에 불리할까',
#  '판사 교체 준법 위정 경 심 이재용 실형 세 가지 요인 은',
#  '코로나 백신 주사기 생산 하는 풍림파마텍 어떤 곳',
#  '제임스 김 암참 회장 이재용 구속 유감 한국 의 독특한 사례 종합',
#  '디케 이티 폴 더블 폰 전기차 부품 매출 증가 기대 리서치 알음',
#  '철강 운송 자동차 가전 분기 이익 추 정치 크게 상향',
#  '이재용 실형 선고 정준영 판사 좌우 진영 모두 에 비판 받는 사연 은',
#  '일 장 마감 후 주요 종목 뉴스',
#  '뉴스 새벽 배송 끝없는 빚투 대출 이자 높이는 은행',
#  '수급 요인 에 가격 변동성 커진 증시 중형 주의 부진',
#  '코스피 마감 대형주 강세 에 대 상승 선 턱밑',
#  '박용진 이재용 형량 불만 있지만 재벌 개혁 첫 발 뗀 것',
#  '윈스 업계 최초 전략 물자 자율 준수 무역 거래 자 등급 획득',
#  '코스피 출렁이자 랩 어 카운트 에 뭉칫돈한투 잔고 조 돌파',
#  '코스피 출렁이자 랩 어 카운트 에 뭉칫돈한투 잔고 조 돌파',
#  '와이 아이 케이 억원 규모 반도체 검사 장비 공급 계약 체결',
#  '외인 기관 동반 매수 에 코스피 급등 선 상회',
#  '특징 주 삼 성 전자 상승 반전',
#  '특징 주 이재용 법정구속 여파 삼성 물산 내리고 오르고',
#  '하루 만에 벗어난 구속 악 재삼 성 그룹 주 일제 상승',
#  '플랜 없는 삼성 계 열사 부문 별 긴급 사 장단 회의 고심',
#  '과거 와는 다르다 총수 부재 삼성 이 직면 한 네 가지 위기',
#  '삼성 준법 위 미래 조언 한 이한상 교수 법적 근거 갖춰야',
#  '이재용 부회장 삼일절 특별 사면 해달라 또 등장',
#  '삼성 전자 삼성 청년 아카데미 기 입학식 개최',
#  '경쟁 에서 관중 된 삼성 당장 문제 없어도 년 년 후 문제',
#  '삼성 전자 화성 사업 장서 코로나 확 진자 발생',
#  '특징 주 삼 성 전자 이재용 법정구속 에 하락 세',
#  '삼성 전기 부품 쇼티 지 수혜 목표 가',
#  '준법 위 일 이재용 구속 후 첫 회의 리스크 유형 화 사업 지원 감시 논의',
#  '내달 부터 코로나 백신 주사기 월 만 개 이상 생산',
#  '이재용 구속 유감 한국 들 사법 리스크 에 경영 차질',
#  '대형주 강세 코스피 대 상승 하며 선 급접',
#  '코스피 기관 외국인 앞세워 상승 출발 선 근접',
#  '밑줄 쫙 문 대통령 이 박 전 대통령 사면 논의 시기상조',
#  '삼성 비상 경영 돌입 계열 사별 경영 체제 강화',
#  '일반 기업 에도 망 개방 년 만에 깨진 주파수 독점',
#  '삼성 전자 소비자 용 에 보 글로벌 시장 출시',
#  '코로나 백신 주사기 양산 삼성 한 팀 으로 뛰었다',
#  '삼성 전자 대 주주 삼성 생명 지 분 상속 누가 받나 삼성 시간 더 달라',
#  '와이 아이 케이 삼 성 전자 와 억 규모 반도체 검사 장비 계약',
#  '이재용 실형 국민 과 하다 가볍다',
#  '동학 개미 전쟁 터 된 삼성 전자 하루 평균 움직였다',
#  '통신사 갤럭시 지 원금 최대 만원 상향 이례 적',
#  '데스크 의 눈 유동성 에 대한 맹신',
#  '코스피 마감 사들인 개미 선 재 탈환',
#  '코스피 대 상승 출발 선 가볍게 돌파',
#  '코로나 에도 곳간 은 든든 현금 천억 이상 상 장사 곳',
#  '코로나 에 막힌 옥중 경영 이재용 월 에야 사 장단 만날 듯',
#  '코로나 에 막힌 옥중 경영 이재용 월 에야 사 장단 만날 듯',
#  '사설 재계 의 이재용 부회장 선처 호소 귀 기울일 만하 다',
#  '미리 보는 이데일리 신 문 고용 창 출 부채 관리 정책 역량 집중 하라',
#  '코스피 슈퍼 비둘기 옐런 에 환호 전자',
#  '존폐 위기 빠진 스마트폰 초콜릿 폰 영광 롤러 블 은 어떡하나',
#  '매경 이 전하 는 세상 의 지식 매세지 월 일',
#  '이재용 수감 됐던 독방 시간 감시 에 화장실 칸막이 도 없어',
#  '특징 주 앤디 포스 애플 협업 관계 부각 애플 카 숨은 수 혜주',
#  '특징 주 앤디 포스 애플 협업 관계 부각 애플 카 숨은 수 혜주',
#  '한 샘 올해 오프라인 출 점 확대 및 시공 확대 유 안타',
#  '모든 가능성 검토 스마트폰 사업 접 나 종합',
#  '재송일 장 마감 후 주요 종목 뉴스',
#  '흔들리는 대형주 코스피 하락 전환 하며 선 하 회',
#  '테스 올해 사상 최대 실적 갱신 전망 업종 최선 호주 유 안타',
#  '리얼미터 국정 농단 연루 이재용 년 개 월 과 하다',
#  '엘리엇 올 봄 삼성 또 침공 하나 지배구조 리스크 커졌다',
#  '장영실 상 삼성 전자 오디세이 게이 밍 모니터',
#  '일 여정 마친 박영선 벤 처 주역 시대 열어',
#  '허탈한 동학 개미 연기금 삼 전 현대차 조 나 팔았다',
#  '삼성 새로 나왔다 테라 까지 종',
#  '존리 주가 하락 시기 맞추는 건 도박 차곡차곡 사들여라 자이앤트',
#  '엘리엇 올 봄 삼성 또 침공 하나 지배구조 리스크 커졌다',
#  '삼성 전자 개인 용 출시',
#  '글로벌 삼성 브랜드 위상 추락 불가피',
#  '매체 삼성 전자 인텔 파운드리 수주 계약',
#  '전자 모바일 철수 설 에 전자부품 예의 주시',
#  '애플 도 탐내는 폴디드 줌 카메라 수 혜주 는 어디',
#  '삼성 만 남았다 스마트폰 시장 지각 변동',
#  '옥중 이재용 준법 위 활동 계속 지원 역할 다해 달라 종합',
#  '시스템 이제 는 비메 모리 불 붙는 시스템 반도체 전쟁',
#  '갤럭시 사 전 예 판 선방 자 급제 판매 배 급증',
#  '강세 에 오늘 도 달리는 개인 코스피 상승 출발 선',
#  '본사 국 이전 에버랜드 무료 개방 이재용 옥중 회견 문 은 가짜',
#  '공매도 금지 로 증시 변동성 확대 됐다',
#  '이재용 구치소 독방 가장 열 악 대우받는다 생각 하면 오산',
#  '코스피 마감 미국 발 훈풍 에 선 돌파 사상 최고',
#  '각종 허들 에도 곱 버스 열기 여 전 불개미 는 아직 배고프다',
#  '재송일 장 마감 후 주요 종목 뉴스',
#  '시스템 한국판 뉴딜 핵심 시스템 반도체 지원 에 팔 걷은 정부',
#  '구글 때리기 지속 광고 사업 경쟁법 위반 예비 조사 돌입',
#  '올해 정기 주 총 개최 가능 거리 두기 인원 제한 규제 예외 키로',
#  '진화 한 삼성 전자 생활 가전 인공 지능 업계 최 다 품목 인증',
#  '미래에셋 순 자산 억원 돌파',
#  '삼성 카드 최대 만원 갤럭시 할인 혜택 제공',
#  '원 익 삼 성 중국 반도체 와 억원 규모 공급 계약',
#  '삼성 준법 위 실효 성 강화 나선다 위원장 권고 불 수용 시 이사회 거쳐야',
#  '삼성 본사 국 이전 언급 한 이재용 옥중 회견 문 은 가짜',
#  '한국 표준 협회 삼 성 전자 에 인증 수여',
#  '삼성 전자 인텔 파운드리 수주',
#  '삼성 생활 가전 개 제품 한국 표준 협회 주관 인증',
#  '코스피 박스 피 년 감안 하면 과열 아니다',
#  '바이든 효과 에 코스피 신고 가',
#  '자 이 앤트 레터 월 가 억만장자 의 경고 현 상승 장 은 미래 의 행복 끌어다 쓴 것',
#  '옥중 이재용 준법 감 시위 역할 다해 달라',
#  '총수 부재 에 경영 도 위기',
#  '창업 가르치기만 하면 될까 기업가 정신 없으면 속 빈 강정',
#  '사설 에 과도 한 형사 책임 묻는 한국 풍토 우려 한 주한 상의',
#  '삼성 준법 위 판결 해명 않겠다 결과 로 실효 성 증명 할 것',
#  '미래에셋 우량 년 만에 순 자산 배 로',
#  '미국 영국 도 이익 공유 해봤는데 최 경선 칼럼',
#  '알뜰폰 시장 봄날 올까 통신사 쏠림 심화 는 숙제',
#  '이재용 준법 감 시위 활동 계속 지 원 위원 들 역할 해달라',
#  '기 자시 한국 만의 독특한 사례',
#  '삼성 준법 위 실효 성 증명 해낼 것 이재용 옥중 요청 에 화답 종합',
#  '시스템 선두 없는 반도체 후 발주 자 삼성 전략 강화 미지수',
#  '삼성 갤 사전예약 시 충전기 만원 할인 쿠폰 추가 증정',
#  '이재용 삼성 준법 감 시위 계속 본연 의 역할 해달라',
#  '삼성 준법 위 실효 성 강화 나선다 위원장 권고 불 수용 시 이사회 거쳐야',
#  '삼 성 카드 로 갤럭시 사면 최대 만원 할인 혜택 제공',
#  '외부 파운드리 확대 의사 내비 친 인텔 영향 은',
#  '인텔 년 프로세서 자체 제조 파운드리 확대 예상',
#  '코스피 기관 외인 동반 매도 에 하락 출발 선',
#  '갤럭시 오늘 부터 사 전 개통 공 시 선약 뭐 가 더 유리할까',
#  '코스피 견조 한 개인 수급 앞세워 상승 전환',
#  '이재용 측 재상 고 여부 일 발표 포기 관측 도',
#  '반도체 부족 국내 도 안심 못 해 장기 화 가능성 높아',
#  '동아 화성 친환경 그린 아이템 에 주목',
#  '삼성 통신 장비 국제 보안 인증 획득 북미 시장 공략 청 신호',
#  '코스피 마감 따라 등락 하락 마감 하며 선 턱걸이',
#  '삼성 롯데 부당 지원 제재 상반기 마무리 대기업 물류 일감 개방',
#  '오늘 갤스 개통 지 원금 선택 약정 뭐 가 유리할까',
#  '특징 주원 익 삼성 전자 법인 과 억 공급 계약 강세',
#  '삼성 전자 인텔 반도체 수 주 절반 의 성공',
#  '삼성 전자 조 투자 해 텍사스 반도체 공장 증설 검토',
#  '빅데이터 로 본 재테크 현대차 사과 하세요 협업 에 전기차 자율 주행',
#  '인텔 파운드리 외주 화 소식 에 알파 홀딩스 껑충',
#  '홈 카페 헬 스케 어 메디 프레 소 억원 브릿지 투자 유치',
#  '인탑스 희망 충전 대한민국 캠페인 에 후 원금 전달',
#  '최은수 기자 의 미래 이야기 바이든 시대 더 위험한 미국 이 온다',
#  '개인 조원 사자 에도 코스피 달성 고배',
#  '특징 주 인텔 파운드리 확대 기 대감 에 반도체 소 부장 급등',
#  '듀얼 벤 더 전략 등 삼성 인텔 손잡을 수 있는 이유',
#  '상 장사 영업 익 상승 예상 무차별 공매도 습격 낮아',
#  '삼성 인텔 위탁 생산 확대 에 기 대감',
#  '삼성 의 파운드리 반격 와 나노 진검 승부',
#  '삼성 전자 조원 투자 해 파운드리 공장 증설 검토',
#  '삼성 전자 통신 장비 국제 공통 보안 인증 획득',
#  '중소 형 의 시간 이 온다',
#  '삼성 조원 투자 해 텍사스 에 반도체 공장 증설 검토',
#  '원 익 억 반도체 장비 수 주 삼 성 전자 후광 효과 에 최대 실적',
#  '동아 화성 전기차 수소차 연료 전지 사업 매력 적 대표 스몰 캡 기업',
#  '켜고 끌때 카톡 카톡 소리 까지 그 들 만의 목소리 찾아 줍니다 인터뷰',
#  '용인 동 문 굿모닝 힐 프레스티지 주상 복합 아파트 월 중 분양',
#  '억 반도체 장비 수주 따낸 원 익년 매출 한 방 에 쑥',
#  '구광모 와 이재용 결단 의 공통점 핵심 역량 안될 사업 버린다 핫이슈',
#  '갤탭 앱 업데이트 아이디 하나로 카톡',
#  '배진솔 의 전자사전 인텔 이 결국 외부 파운드리 의지 어떤 의미 일까',
#  '복를 찾아서 내 첫 핸드폰 애니콜 이 돌아왔다',
#  '가 원하는 건 화웨이 의 죽음 런정 페이 연설 뒤늦게 공개 이유 는',
#  '재계 프리즘 전자 주 총 을 확대 하 라',
#  '삼성 약 조 투자 해 반도체 공장 건설 검토',
#  '기업 옥죄 기일 뿐 이익공유제 등 코로나 법 추진 에 재계 울상',
#  '기업 옥죄 기일 뿐 이익공유제 금융 울 고 산업 계 는 불안',
#  '주목 스몰 캡 실적 반등 의 해 차전지 검사 장비 기업 브이 원 텍',
#  '증시 캘린더 이번 주 월 주 선진 뷰티 사이언스 등 코스닥 신규 상장',
#  '미리 보는 이데일리 신문 일자리 밀려난 청년 탁상 대책 이 더 아프다',
#  '갤럭시 첫 출발 나쁘지 않다 아이폰 잡 을 수 있을까',
#  '올해 대세 는 미니 주목 할 관련 는',
#  '윤 태식 기재부 차관 보 구글 삼성 디지털 세 방식 달라 야',
#  '주 간증 시 전망 바이든 시대 첫 결국 은 실적',
#  '코스피 주간 기관 순 매도 위 삼 성 전자 우',
#  '삼성 전자 공장 투자 조 더',
#  '비 스포크 넣고 위생 관리 까지 삼성 년 형 무풍 에어컨 공개',
#  '삼성 전자 실적 발표 에 쏠린 시선 와 파운드리 전쟁 가열',
#  '덜 오른 중소형주 탐색 해볼까 흥국 머티리얼즈 씨 에스 윈드 한솔 케미칼',
#  '공매도 재개 되도 대형 주가 영향 없을 것',
#  '이익공유제 원조 정운찬 마저 상생 법 은 억지 정책',
#  '단독 애플 강국 한국 에 손짓 스노우 같은 대박 앱 또 만들자',
#  '대기업 들어오고 교통 길 뚫리 고호 재 날개 단 평택 주택 시장',
#  '자 이 앤트 레터 터키 와 맞먹는 시장 리틀 버핏 이 주목 하는 이 기업',
#  '불 붙은 대형주 강세 장 언제 까지 갈까',
#  '갤럭시 이틀 새 만 대 전작 대비',
#  '부동산 큰손 도 증시 로 대이동',
#  '코로나 뚫고 유럽 누 볐는데 또 멈춘 이재용 의 글로벌 행보',
#  '이번 주 실적 시즌 분기 실적 보다 이 것 을 보라',
#  '삼성 년 형 비 스포크 무풍 에어컨',
#  '삼성 본사 이전 언급 한 이재용 옥중 회견 문 은 가짜 였다',
#  '삼성 인텔 투자 의 정석 반도체 의 모든 것 알려 드립니다',
#  '단독 상가 판 억 으로 삼성 전자 테슬라 샀다',
#  '층 에 사람 있어요 삼 성전 자 게 걸음 에 속 타 는 동학 개미',
#  '코스피 주간 개인 순 매수 위 삼성 전자',
#  '손학규 이재용 부회장 을 사면 하 라 대통령 고민 많을 것',
#  '경기 반등 기 대감 에 코스피 는 코스닥 은 선',
#  '코로나 로 대중 들 관심 도 에 삼성 높고 호감 도 에 높아졌다',
#  '마켓 인 신생 스케일 업 파트너 스 모태 펀드 출사표',
#  '삼성 개 월간 총수 공백 옥중 경영 차질 가능성 도',
#  '도 넘은 공매도 포퓰리즘 기 자시',
#  '특검 재상 고 않겠다 이재용 년 개월 형 확정',
#  '이 부회장 측 겸허 히 받아들이고 재상 고 안 하기로',
#  '특징 주 반도체 삼성 테슬라 맞 손 나노 반도체 개발 에 강세',
#  '이재용 재상 고 안 한다 판결 겸허 히 수용',
#  '코스피 도 뚫었다 버블 후 천스닥 눈 앞',
#  '방 많아 스마트폰 필요 없다던 휴대폰 베트남 품 으로',
#  '기아차 삼성 전자 코스피 거품 경고 비웃듯 날아간다',
#  '기아차 삼성 전자 코스피 거품 경고 비웃듯 날아간다',
#  '삼성 사활 건 투자 전쟁 중 소형 반도체 는 웃는다',
#  '이재용 판결 겸허 히 수용 재상 고 포기 삼성 준법 경영 고삐',
#  '반도체 생산 좀 늘려줘 전세계 가 대만 에',
#  '테스 메모리 가격 상승 에 업황 반등 기대',
#  '스마트 공장 시대 활짝 상 멘토 삼성 등 대기업 도 통큰 지원',
#  '코스닥 마감 외국인 기관 끌어 올리니 천 스닥 바짝',
#  '코스피 개인 사자 에 대 상승',
#  '코스피 마감 선 돌파 외인 기관 덕 에 종가 최고 치',
#  '열네 살 주식 수익 인증 만원 제주 초등생 의 투자비법',
#  '코스피 기관 사자 에 장 중 선 회복',
#  '김정호 교수 디지털 공학 미래 담은 신간 출 간',
#  '특검 도 국정 농단 재상 고 않기로 이재용 징역 년 개 월 확정 종합 보',
#  '스마트 공장 시대 활짝 상 코로나 백신 주사기 생산 량 배 껑충',
#  '이재용 재상 고 여부 오늘 결정 포기 에 무게',
#  '이재용 재상 고 안 해 특검 포기 시 징역 년 개 월 확정 종합',
#  '특징 주 테스 올해 최대 실적 기 대감 에 강세',
#  '속보 이재용 측 판결 겸허 히 받아들여 재상 고 안해',
#  '스마트 공장 시대 활짝 상 생산 성 향상 위해 데이터 관리 등 지원 해야',
#  '코스피 개인 사자 에 상승 출발 선',
#  '퇴근길 뉴스 아이언 왜 거주지 아닌 다른 아파트 서 발견 됐나',
#  '이재용 옥중 메시지 삼성 가야 할길 가야 투자 고용 본분 충실히',
#  '이재용 첫 옥중 메시지 삼성 은 가야 할 길 계속 가야 한 다 전문',
#  '갤스 울트라 에 적용 한 디스플레이 뭔 가보 니 삼성 디스플레이 신상',
#  '네이버 삼성 등 선점 나서 분 의 초 다투는 서비스 경쟁',
#  '사상 첫 온라인 행사 로 팬데믹 뉴 노멀 제시 똑똑한 재택 위 한 스',
#  '준법 강조 한 이재용 국민 들 께 드린 약속 반드시 지켜야',
#  '코스피 역대 최고 거품 논란 에도 목표 가 상향 톱 종목 은',
#  '부산시 넘버 모두 비었다 권한 대행 마저 출마',
#  '화웨이 까지 술렁대는 스마트폰 제조업 아이티 라떼',
#  '먹여 살리는 반도체 기술 에 빼 돌리려던 일당 기소',
#  '레이더 국내 시스템 반도체 투자 트렌드 는 팹리스 디자인 하우스',
#  '경실련 박범계 법무부 장관 후보 사퇴 해야',
#  '이재용 부회장 구속 으로 삼성 투기 자본 먹잇감 되나',
#  '단독 갤럭시탭 에서도 카톡 정말 된다오 늘 부터 앱 업데이트 시작',
#  '갤 디스플레이 소비전력 은 줄었다',
#  '달아오른 증시 온도 일 에 달렸다',
#  '경실련 박범계 법무부 장관 후보 사퇴 해야',
#  '삼성 준법 위 실효 성 위해 위원 에 사외이사 자격 줄까',
#  '이재용 삼성 투자 고용 충실 해달라',
#  '빈 그룹 천억원 채권 발행 휴대폰 사업 인수 포석',
#  '네이버 회사 도 통신사 될 수 있다 사업 성 은 지켜봐야',
#  '갤럭시탭 전용 카톡 출시 오늘 부터 업데이트',
#  '코스닥 마감 외인 기관 동반 매 도선 터치 후 하락',
#  '신 사업 노크 하는 위니 아 딤채 이번 엔 백신 냉장고',
#  '차량 용 반도체 품귀 반도체 희비 엇갈린 까닭 은',
#  '단독 위니 아 딤채 백신 냉장고 개발 착수 신 사업 적극 발굴',
#  '만원 짜리 갤럭시 만원 대 에 출시 전 부터 판촉 전 후끈',
#  '오는 일 부터 귀금속 마스크 줄 한정 판매',
#  '갤럭시 출시 에 알뜰폰 무제한 요 금제 가입자 배',
#  '코스피 외인 기관 팔자 에 하락 출발 선',
#  '코스피 외인 기관 팔자 에 대 하락 선',
#  '코 아시아 시스템 반도체 호황 기 대감 에 올해 주가 쑥',
#  '이재용 부회장 구속 으로 삼성 투기 자본 먹잇감 되나',
#  ...]

# %%
title_text = ''

for each_line in news_list:
    title_text = title_text + each_line + '\n'
    
title_text
# Out:
# '낡은 규 제혁 파세계 최고 상속 세율 기업인 에 사망 선고 재계 상속 세율\n낡은 규 제혁 파 암세포 같은 낡은 규제 가 한국 경제 혁신 막는다\n머리카락 배 얇은 초 박막 렌즈 개발 스마트폰 카툭 튀 없앤다\n월 효과 연말 랠리 잇는다 증권 가 실적 개선 경기 민감 주목\n낡은 규 제혁 파세계 최고 상속 세율 기업인 에 사망 선고 재계 상속 세율\n갤럭시 이번 엔 티저 영상 유출 새로운 갤럭시 가 기다리고 있다\n밑줄 쫙 국정 농단 대미 장식 특검 이재용 에 징역 년 구형\n코스피 시 총 사상 최초 넘어선 듯 삼전 조원 증가\n경제 기상도 코로나 에 갇혔던 경제 소의 뿔 처럼 저돌 적 돌파 기대\n반도체 메모리 값 강세 지 속 파운드리 수요 도 늘듯\n디스플레이 더 선명해진 프리미엄 시장 선점\n가전 집콕 수혜 백색 가전 상반기 까지 돌풍 예고\n스마트폰 중 저가 폰 라인업 확대 두 자릿수 성장 노려\n애플 폰 출시 두 달새 삼성 판매량 추월\n주식 부호 조 클럽 명 김범수 카카오 의장 순위 껑충\n장기 자의 비사 이드 크리스마스 는 아이폰 이 접수\n애플 카 전자 의 야심작 롤러 블 이 달 첫 선 어떻게 생겼나\n슈퍼 리치 재테크 스타 가 조언 하는 올해 주목 할 테마\n품질 로 경쟁 선언 반년 만에 명칭 놓고 삼성 신 경전\n대 그룹 시무 식 일 온라인 개최 이재용 신년사 없을 듯\n장기 자의 비사 이드 크리스마스 는 아이폰 이 접수\n주목 스몰 캡 살아나는 반도체 업황 기회 찾아온 아이 원스\n유 안타 주간 추천 주 매출 반등 예상 삼 성전 자 아모레퍼시픽 엔씨 소프\n단독 주린이 삼성로 몰리나 현대차 배터리 공급 후보 낙점\n삼성 전자 여전히 저 평가 전문가 새해 톱픽 추천\n삼성 패스 로 연말정산 을 전자서명 시장 본격 진출\n국내 가입자 천만 명 돌파 올해 대중화 단계\n펀드 와 치 사상 최고 치 코스피 레버리지 펀드 껑충\n국내 가입자 천만 명 돌파 제재 로 새해 폰 애플 위\n주 간증 시 전망 어 닝 시즌 진입 월 효과 시동 걸까\n이재용 부회장 경영 에 전념 하게 해달라 국민 청원 등장\n스페셜 리포트 삼성 명 포스코 명 시가총액 증가 기업 사장 승진 많았다\n코스피 주간 외국인 순 매도 위 삼성 전자\n코스피 주간 개인 순 매수 위 삼성 전자\n주간 추천 주 업황 개선 기대 러브콜 삼성 전자 등\n삼성 분기 잠정 실적 발표 임박 코로나 수혜 이어지나\n지난해 폰 위 는 화웨이 위 는 애플 삼성 위\n삼성 전자 국내 최고 수준 화 력 비 스포크 인덕션 신제품 출시\n숫자 로 보는 년 주식시장\n돈터뷰 깡통 번 차고 비로소 습득 한 슈퍼 개미 필살기\n스페셜 리포트 대기업 의 자격 현대차 글로벌 전략 디지털 역량\n이재용 경 영 전념 토록 선처 청원 에 만 명 동의\n만원 인덕션 벤츠 보다 비싼 초고 가 가전 초 호황\n위기 때 버팀목 은 실적 장 세\n메 리츠 지금 은 대세 상승 초입 년 까지 구조 적 상승 장\n천 고지 앞둔 코스닥 반도체 바이오 가 견인\n황소 가 된 개미 주가 시대 연 다\n김기남 삼성 전자 부회장 신년사 년 은 변화 대응 하고 미래 준비 하는 원년\n신년사 김기남 삼성 전자 부회장 삼성 만의 지속 가능 경영 발전 시키자\n삼성 전자 업황 회복 유동성 유입 목표 가 하이\n삼성 전자 실적 줄어도 목표 가 오른다 이유 는\n삼성 전자 에너지 소비 효율 등급 상업 용 에어컨 확대\n텔레콤 로 시작 하고 끝낸다 빅 테크 속도\n늘어난 배당 성향 코스피 발판\n한 달 빨라진 삼성 전자 언 팩 행사 일 요술 봉 든 괴물 폰 나온다\n최고 가 랠리 삼성 전자 목표 주가 만원 나왔다\n삼성 전자 를 넘어 까지 선점 시스템 반도체 조 공격 적 투자\n이재용 삼성 협력 사와 손잡고 시스템 반도체 신화 쓸것\n새해 재테크 전략 명의 조언 주식 비중 늘려라\n사실 상 안방 인데 도 애플 에 밀려 위 씁쓸한 삼성\n년 미니 시대 세진 티에스 삼성 전자 핵심 공급 업체 로 주목\n신축년 대세 바로 나 컬러풀 주방 가전 쏟아진다\n황소 의 해 힘찬 개장 코스피 눈앞\n이재용 식 승 어부 첫 발 은 협력 사와 상생\n재계 가 뛴다 소 처럼 우직하게 기업 올해 도 위기 돌파 앞장선다\n고객 선택 받는건 오직 기술 경쟁력 어려워도 우수 인재 투자 계속 할 것\n기업 영업 익 이상 증가 최고 갈수 도\n이노 폭등 화학 삼성 최고 가 새해 랠리 첫 주자\n황 성우 삼성 사장 코로나 에도 디지털 전환 은 계속 기술 활용 해 고객\n삼성 전자 반도체 업황 회복 효과 목표 가 하이\n최고 기술 장인 삼성 명장 명 선발\n아이폰 잡으러 출격 삼성 일 갤럭시 조기 등판\n스톡 톡스 코스피 분기 는 상승세 유지 반도체 자동차 주목\n삼성 과 년 걸어온 협성회 매출 조 클럽 회원 사도 곳 동반 성장\n인터뷰 양 향 자 중대 재해 법 산업 계 마크 도입 으로 풀자\n이색 테마 적용 된 상업시설 브리티시 고덕 뛰어난 가시 성과 높은 집객 력\n중국군 통제 기업 투 자금 치 조치 국내 억원 유입\n스톡 톡스 개미 의 힘 이번 주 코스피 갈 수도\n소 띠 해 첫 날 나타난 황소 동학 개미 가 고삐 쥐었다\n스톡 톡스 긍정 재료 선 반영 펀더 멘털 괴리 유의 해야\n코스피 마감 조 담은 동학 개미 덕 에 신축년 첫날 선 기염\n동학 개미 덕 에 년 개장 일 코스피 상승 출발\n코스피 첫 거래 일 사상 첫 선 돌파 동학 개미 의 힘\n스톡 톡스 테슬라 판매 반도체 수출 호조 코스피 더 간다\n이재용 놔 달라 국민 청원 에 만 여명 동의\n신축년 슈퍼 사이클 에 주성 등 반도체 장비 주목\n전기차 가 받치고 반도체 가 끌어 올리니 코스피 선\n고지 가 보인다 코스피 상승 폭 확대 해 선 돌파\n서 베이 한국 주식 은 반도체 해외 주식 은 신 재생 에 주목\n서 베이 한국 주식 은 반도체 해외 주식 은 신 재생 에 주목\n미니 마이크로 새해 시장 신제품 격돌\n대 그룹 새해 핵심 경영 키 워드 고객 중심 사회 적 책임\n차 화 전이 열 일 했다 코스피 선 주역\n이재용 승 어부 첫 발 협력 사와 평택 파운드리 공장 찾아 상생 다짐\n삼성 언 팩 초대장 드디어 공개 혁신 적 인 카메라 예고\n삼성 새해 경영 핵심 키워 드는 고객 종합\n이재용 부회장 새로운 삼성 도약 시스템 반도체 신화 만들자\n삼성 최고 기술 전문가 삼성 명장 명 선정 디 플 첫 선발\n통신사 랜선 시무 식 신년 화두 는 고객\n지난해 스마트폰 출 하량 억 만대 돌파 애플 이 점령\n오늘 의 부고 종합\n코스피 시 간문제 가지 리스크 반드시 염두 에 둬라\n매경 이 전하 는 세상 의 지식 매세지 월일\n뇌 기억 유지 법 연구 한국 논문 네이처 에\n취업 축하 땐 밝게 급전 고객 엔 안타까운 표정 사람 닮은 은행원 월 등장\n이재용 더 바빠진 현 장경영\n신년 기획 미래 산업 훅 들어온 시대 차세대 동력 잡아야 글로벌 리더\n대형주 만 오르 네 코스피 시 총 톱 비중 육박\n아이티 라떼 충전기 없애는 애플 삼 성 환경보호 냐 환경 파괴 냐\n삼성 판 현대 오토 에버 될까 삼성 하루 새 급등\n삼성 전자 탑재 세탁기 건조기 출품 시장 본격 공략\n삼성 이 지원 한 정원석 연구 팀 자폐 치매 치료 새 전기 마련\n삼성 비 스포크 시장 본격 진출\n애플 배 퀄컴 배 만 전자 삼성 여전히 배고파\n삼성 전자 이 그리는 빅 피처\n삼성 물산 패션 부문 삼 성 전자 와 공동 마케팅\n만 전자 도 부족하다 삼성 전자 목표 가 줄 상향\n시가총액 조원 시대 연 삼성 전자 목표 가 만원 등장 시 총 조 의미\n삼성 전자 갤럭시 캠퍼스 스토어 오픈 대학 대학원생 특별 혜택\n정경 심 항소심 특검 과 설전 이재용 파기 환송 심 재판 부 에 배당\n엔씨 백만 소프트 의 꿈 실현 할까 신작 모멘텀 다수\n부음 소수 길씨 별세 외\n갤럭시 플립 혁신 성 일본 서도 인정\n정경 심 심 이재용 국정 농단 파기 환송 심 재판 부가 맡는다\n김진욱 초대 공 수 처 장 후보자 재산 억 소유 부동산 은 없어\n유경 좋은 생각 자산 배분 형 펀드 저 평가 담았더니 년 수익률\n신년사 키 워드 로 본 신축년 기업 전략 고객 성장 우선\n슈퍼 사이클 온다 증시 문 두드리는 반도체 장비 업체 들\n반도체 슈퍼 사이클 다 ...

# %%
tokens_ko = okt.morphs(title_text)

# %%
import nltk
ko = nltk.Text(tokens_ko)
ko
# Out:
# <Text: 낡은 규 제혁 파세계 최고 상속 세율 기업인...>

# %%
print(len(ko.tokens))          # 토큰 전체 개수
print(len(set(ko.tokens)))
# Out:
# 60958
# 8395

# %%
# 빈도수가 높은 단어 출력

ko.vocab().most_common(200)
# Out:
# [('\n', 5482),
#  ('삼성', 1830),
#  ('전자', 1155),
#  ('에', 1009),
#  ('반도체', 581),
#  ('코스피', 518),
#  ('이재용', 377),
#  ('의', 376),
#  ('이', 330),
#  ('한', 291),
#  ('가', 275),
#  ('투자', 265),
#  ('선', 261),
#  ('도', 259),
#  ('은', 258),
#  ('성', 256),
#  ('로', 249),
#  ('는', 246),
#  ('주', 237),
#  ('대', 234),
#  ('삼', 234),
#  ('위', 233),
#  ('조', 231),
#  ('기업', 225),
#  ('년', 209),
#  ('갤럭시', 206),
#  ('만', 204),
#  ('마감', 176),
#  ('일', 175),
#  ('상승', 175),
#  ('실적', 170),
#  ('출시', 153),
#  ('기관', 145),
#  ('장', 144),
#  ('포토', 141),
#  ('월', 134),
#  ('들', 134),
#  ('전', 134),
#  ('개미', 133),
#  ('서', 133),
#  ('사면', 130),
#  ('코로나', 129),
#  ('으로', 128),
#  ('분기', 127),
#  ('까지', 120),
#  ('하락', 120),
#  ('총', 118),
#  ('외국인', 118),
#  ('시장', 117),
#  ('순', 115),
#  ('기술', 115),
#  ('더', 114),
#  ('매수', 113),
#  ('등', 112),
#  ('와', 111),
#  ('한국', 110),
#  ('출발', 109),
#  ('자', 108),
#  ('개인', 108),
#  ('하이닉스', 108),
#  ('폰', 104),
#  ('최대', 104),
#  ('과', 103),
#  ('억', 103),
#  ('종합', 100),
#  ('최고', 99),
#  ('중', 99),
#  ('첫', 98),
#  ('만원', 98),
#  ('목표', 98),
#  ('기', 98),
#  ('적', 97),
#  ('가전', 96),
#  ('사업', 96),
#  ('매도', 94),
#  ('시', 93),
#  ('올해', 93),
#  ('주식', 92),
#  ('지', 91),
#  ('것', 91),
#  ('외인', 91),
#  ('증시', 90),
#  ('글로벌', 89),
#  ('공급', 87),
#  ('주가', 87),
#  ('공장', 87),
#  ('스마트폰', 86),
#  ('비', 86),
#  ('이건희', 84),
#  ('종목', 84),
#  ('에도', 83),
#  ('개', 83),
#  ('대통령', 83),
#  ('동학', 82),
#  ('경영', 81),
#  ('회장', 81),
#  ('확대', 79),
#  ('화', 79),
#  ('영업', 79),
#  ('산업', 79),
#  ('애플', 78),
#  ('명', 77),
#  ('부회장', 77),
#  ('전망', 76),
#  ('익', 76),
#  ('돌파', 75),
#  ('지원', 75),
#  ('제', 75),
#  ('경제', 74),
#  ('수', 74),
#  ('원', 74),
#  ('파운드리', 73),
#  ('하는', 72),
#  ('주간', 72),
#  ('세계', 72),
#  ('스포크', 71),
#  ('인', 71),
#  ('세', 70),
#  ('장비', 70),
#  ('이데일리', 70),
#  ('조원', 69),
#  ('성장', 69),
#  ('억원', 69),
#  ('주목', 68),
#  ('후', 68),
#  ('인텔', 68),
#  ('배당', 67),
#  ('카카오', 66),
#  ('만에', 66),
#  ('신', 66),
#  ('고', 64),
#  ('업계', 64),
#  ('금리', 64),
#  ('속', 63),
#  ('상', 63),
#  ('형', 63),
#  ('하', 63),
#  ('증권', 62),
#  ('엔', 62),
#  ('그룹', 62),
#  ('백신', 62),
#  ('사상', 61),
#  ('사', 61),
#  ('단독', 60),
#  ('규모', 60),
#  ('뉴스', 60),
#  ('생산', 60),
#  ('국내', 59),
#  ('부터', 59),
#  ('달', 58),
#  ('경', 58),
#  ('공개', 57),
#  ('공매도', 57),
#  ('개발', 56),
#  ('할', 56),
#  ('경쟁', 56),
#  ('다', 56),
#  ('주요', 56),
#  ('정부', 56),
#  ('배', 55),
#  ('현대차', 53),
#  ('시스템', 53),
#  ('미리', 53),
#  ('을', 52),
#  ('보는', 52),
#  ('국민', 51),
#  ('전략', 51),
#  ('용', 51),
#  ('역대', 51),
#  ('매출', 50),
#  ('펀드', 50),
#  ('나', 50),
#  ('해', 50),
#  ('강세', 49),
#  ('대기업', 49),
#  ('협력', 49),
#  ('작년', 49),
#  ('준법', 49),
#  ('에서', 49),
#  ('슈퍼', 48),
#  ('보합', 48),
#  ('사자', 48),
#  ('우려', 48),
#  ('초', 47),
#  ('시대', 47),
#  ('오늘', 47),
#  ('권', 47),
#  ('또', 47),
#  ('본격', 46),
#  ('디지털', 46),
#  ('된', 46),
#  ('전환', 46),
#  ('공', 46),
#  ('문', 46),
#  ('하나', 46),
#  ('이익', 46),
#  ('회복', 45),
#  ('동반', 45),
#  ('해야', 45),
#  ('차', 45)]

# %%
# 불용어(stopwords) 제거하기

stop_words = ['\n',"'",'…',',','[',']','(',')','"','주','에','코스닥','특징','종목','·','장','코스피','증시','-','적',\
              '도','기술','분석','마감','‘','`','요약','가','’','의','이','오전','★','은','“','대','”','한','B','로',\
              '?','3','선','A','오후','는','5','!','"…','상','들','1','만에','제','2','…"','20','일','서','명',"'…",'기',\
              '···','10','소','등','으로','자','전','률','미','...','50','세','시','안','폭',"…'",'만','9','VI','까지',\
              '눈','더','e','량','고','인','52','성','띄네','1%','부터','다','감','을','지','4','에도','수','7','것','째',\
             '체크','기','···','중','계','관련','왜','1억원','총','내','과','젠','또','연','엔','차','굿모닝','할','8','.',\
             '보다','새','주간','전망','추천','이슈','플러스','사','개월','때','..','임','속','’…','G','나','개','원','에서',\
             '하는','이유','달','→','권','?…','단독','간','배','30','K','저','와','하','/','1조','6','두','해야','분','형',\
             '황','공','&','앞두고','보','문','이번','익','X','1억',']"','치','산','를','오','해','S','우리','그','된','준','▶',\
             '건','재','반','라','10년','초','3분','월','신','p','급','조','줄','경','했다','구','진','이어','올','발','vs','강',\
             '국','9억','1년','난','판','면','"(','`…','살','아','인데','번','텍','팜','8월','Q','메','2년','점','하고','10월',\
             'D','비','됐다','채',"]'",'보니','손','확','종','동','팔','40','타','~','9월','2100','30%','땐','말','한다','요',\
             "',",'스','…`','단','16','길','12','3억','회','될까','호','용','2조','번째','일까','듯','최']

tokens_ko = [each_word for each_word in tokens_ko
           if each_word not in stop_words]

ko = nltk.Text(tokens_ko)
ko.vocab().most_common(100)
# Out:
# [('삼성', 1830),
#  ('전자', 1155),
#  ('반도체', 581),
#  ('이재용', 377),
#  ('투자', 265),
#  ('삼', 234),
#  ('위', 233),
#  ('기업', 225),
#  ('년', 209),
#  ('갤럭시', 206),
#  ('상승', 175),
#  ('실적', 170),
#  ('출시', 153),
#  ('기관', 145),
#  ('포토', 141),
#  ('개미', 133),
#  ('사면', 130),
#  ('코로나', 129),
#  ('분기', 127),
#  ('하락', 120),
#  ('외국인', 118),
#  ('시장', 117),
#  ('순', 115),
#  ('매수', 113),
#  ('한국', 110),
#  ('출발', 109),
#  ('개인', 108),
#  ('하이닉스', 108),
#  ('폰', 104),
#  ('최대', 104),
#  ('억', 103),
#  ('종합', 100),
#  ('최고', 99),
#  ('첫', 98),
#  ('만원', 98),
#  ('목표', 98),
#  ('가전', 96),
#  ('사업', 96),
#  ('매도', 94),
#  ('올해', 93),
#  ('주식', 92),
#  ('외인', 91),
#  ('글로벌', 89),
#  ('공급', 87),
#  ('주가', 87),
#  ('공장', 87),
#  ('스마트폰', 86),
#  ('이건희', 84),
#  ('대통령', 83),
#  ('동학', 82),
#  ('경영', 81),
#  ('회장', 81),
#  ('확대', 79),
#  ('화', 79),
#  ('영업', 79),
#  ('산업', 79),
#  ('애플', 78),
#  ('부회장', 77),
#  ('돌파', 75),
#  ('지원', 75),
#  ('경제', 74),
#  ('파운드리', 73),
#  ('세계', 72),
#  ('스포크', 71),
#  ('장비', 70),
#  ('이데일리', 70),
#  ('조원', 69),
#  ('성장', 69),
#  ('억원', 69),
#  ('주목', 68),
#  ('후', 68),
#  ('인텔', 68),
#  ('배당', 67),
#  ('카카오', 66),
#  ('업계', 64),
#  ('금리', 64),
#  ('증권', 62),
#  ('그룹', 62),
#  ('백신', 62),
#  ('사상', 61),
#  ('규모', 60),
#  ('뉴스', 60),
#  ('생산', 60),
#  ('국내', 59),
#  ('공개', 57),
#  ('공매도', 57),
#  ('개발', 56),
#  ('경쟁', 56),
#  ('주요', 56),
#  ('정부', 56),
#  ('현대차', 53),
#  ('시스템', 53),
#  ('미리', 53),
#  ('보는', 52),
#  ('국민', 51),
#  ('전략', 51),
#  ('역대', 51),
#  ('매출', 50),
#  ('펀드', 50),
#  ('강세', 49)]

# %%
import matplotlib.pyplot as plt

# %%
# 그래프에서 한글 폰트 깨지는 문제에 대한 대처(전역 글꼴 설정)

from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname='c:/Windows/Fonts/malgun.ttf').get_name()
rc('font', family=font_name)

import graphviz
plt.figure(figsize=(15,6))
ko.plot(50)
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS
from PIL import Image

# %%
data2 = ko.vocab().most_common(300)
wordcloud = WordCloud(font_path='c:/Windows/Fonts/malgun.ttf',
                     relative_scaling=0.2,
                     background_color='white').generate_from_frequencies(dict(data2))

plt.figure(figsize=(16,8))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
data
# Out:
#             Date                                           기사제목    Close  \
# 0     2021-01-01  [낡은규제혁파①]"세계 최고 상속세율, 기업인에 사망선고"…재계, 상속세율 ...  83000.0
# 1     2021-01-01            [낡은규제혁파①]암세포 같은 낡은 규제가 한국 경제 혁신 막는다  83000.0
# 2     2021-01-01           머리카락 100배 얇은 초박막렌즈 개발…스마트폰 `카툭튀` 없앤다  83000.0
# 3     2021-01-01             1월효과, 연말랠리 잇는다…증권가 "실적개선·경기민감株 주목"  83000.0
# 4     2021-01-01  [낡은규제혁파①]"세계 최고 상속세율, 기업인에 사망선고"…재계, 상속세율 ...  83000.0
# ...          ...                                            ...      ...
# 5479  2021-06-29                  삼성전자 "美공장부지 선정 못했다"…핵심은 '칩스법'  80700.0
# 5480  2021-06-29         삼성 'SSAFY'·SK '하이파이브'…정부 지원으로 3천명+α 확대  80700.0
# 5481  2021-06-29               삼성전자, 2Q 영업익 11조원 초반대…반도체 견인-IBK  80700.0
# 5482  2021-06-29               삼성·LG전자, 2분기 실적도 '훨훨'…내주 잠정실적 발표  80700.0
# 5483  2021-06-29        삼성전자, 사내외 벤처 인큐베이팅 가동…5년동안 500개 프로젝트 육성  80700.0
#
#         Change   등락구분  label  주가 반영 Date  \
# 0     0.024691   True    1.0  2021-01-04
# 1     0.024691   True    1.0  2021-01-04
# 2     0.024691   True    1.0  2021-01-04
# 3     0.024691   True    1.0  2021-01-04
# 4     0.024691   True    1.0  2021-01-04
# ...        ...    ...    ...         ...
# 5479 -0.003704  False   -1.0  2021-06-30
# 5480 -0.003704  False   -1.0  2021-06-30
# 5481 -0.003704  False   -1.0  2021-06-30
# 5482 -0.003704  False   -1.0  2021-06-30
# 5483 -0.003704  False   -1.0  2021-06-30
#
#                                                   형태소분석
# 0     [낡은, 규, 제혁, 파세계, 최고, 상속, 세율, 기업인, 에, 사망, 선고, 재...
# 1     [낡은, 규, 제혁, 파, 암세포, 같은, 낡은, 규제, 가, 한국, 경제, 혁신,...
# 2        [머리카락, 배, 얇은, 초, 박막, 렌즈, 개발, 스마트폰, 카툭, 튀, 없앤다]
# 3       [월, 효과, 연말, 랠리, 잇는다, 증권, 가, 실적, 개선, 경기, 민감, 주목]
# 4     [낡은, 규, 제혁, 파세계, 최고, 상속, 세율, 기업인, 에, 사망, 선고, 재...
# ...                                                 ...
# 5479          [삼성, 전자, 공장, 부지, 선정, 못, 했다, 핵심, 은, 칩스, 법]
# 5480                    [삼성, 하이파이브, 정부, 지원, 으로, 천명, 확대]
# 5481                [삼성, 전자, 영업, 익, 조원, 초반, 대, 반도체, 견인]
# 5482            [삼성, 전자, 분기, 실적, 도, 훨훨, 내주, 잠정, 실적, 발표]
# 5483  [삼성, 전자, 사, 내외, 벤, 처, 인큐, 베이, 팅, 가동, 년, 동안, 개,...
#
# [5484 rows x 8 columns]

# %%
# 형태소 분석을 위한 함수

def tokenizer(text):
    okt = Okt()
    return okt.morphs(text)

# %%
def data_preprocessing():
    # 수집한 데이터 읽어오기
    # data=pd.read_csv('df_fin.csv')
    
    # 학습셋, 테스트셋 분리
    title_list = data['기사제목'].tolist()
    price_list = data['label'].tolist()
    
    from sklearn.model_selection import train_test_split
    
    # 데이터의 80%는 학습셋, 20%는 테스트셋
    title_train, title_test, price_train, price_test = train_test_split(news_list, price_list, test_size=0.2, random_state=0)
    
    return title_train, title_test, price_train, price_test

# %%
def learning(x_train, y_train, x_test, y_test):
    # 전처리가 끝난 데이터를 단어 사전으로 만들고
    # 리뷰별로 나오는 단어를 파악해서 수치화 (벡터화)해서 학습
    # tfidf, 로지스틱 회귀 이용
    
    tfidf = TfidfVectorizer(lowercase=False, tokenizer=tokenizer)
    # 로지스틱
    logistic = LogisticRegression(C=2, penalty='l2', random_state=0)     # C의 숫자가 너무 크면 과적합 (기본 1), penalty로 과적합 방지
    
    pipe = Pipeline([('vect',tfidf),('clf',logistic)])
    
    # 학습
    pipe.fit(x_train, y_train)
    
    # 학습 정확도 측정
    y_pred = pipe.predict(x_test)
    print(accuracy_score(y_test, y_pred))
    
    # 학습한 모델을 저장
    with open('pipe.dat', 'wb') as fp:     # 쓰기, 바탕화면에 저장됨
        pickle.dump(pipe, fp)
        
    print('저장완료')     # 학습된 모델 저장 완료

# %%
def using():
    # 객체를 복원, 저장된 모델 불러오기
    with open('pipe.dat','rb') as fp:     # 읽기
        pipe = pickle.load(fp)
        
    while True :
        text = input('뉴스 타이틀을 입력해주세요 : ')     # 인풋
        
        str = [text]
        
        # 예측 정확도
        r1 = np.max(pipe.predict_proba(str)*100)     # 확률값을 구해서 *100..?
        
        # 예측 결과
        r2 = pipe.predict(str)[0]     # 긍정('1'), 부정('0')
        
        if r2 == '1':
            print('코스피지수는 상승할 것으로 예상됩니다.')
        else: 
            print('코스피지수는 하락할 것으로 예상됩니다.')
            
        print('정확도 : %.3f' % r1)
        print('------------------------------------------------')

# %%
# 학습 함수

def model_learning():   # 감성분석 모델 생성
    title_train, title_test, price_train, price_test = data_preprocessing()
    learning(title_train, price_train, title_test, price_test)
    
# 사용 함수

def model_using():   # 감성분석 모델 사용
    using()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer 
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score
import pickle
import numpy as np

# %%
model_learning()
# Out:
# 0.601640838650866
# 저장완료

# %%
model_using()
# Out:
# 뉴스 타이틀을 입력해주세요 : 삼성
# 코스피지수는 하락할 것으로 예상됩니다.
# 정확도 : 50.293
# ------------------------------------------------
# 뉴스 타이틀을 입력해주세요 : 이재용
# 코스피지수는 하락할 것으로 예상됩니다.
# 정확도 : 83.798
# ------------------------------------------------
# 뉴스 타이틀을 입력해주세요 : 갤럭시
# 코스피지수는 하락할 것으로 예상됩니다.
# 정확도 : 81.025
# ------------------------------------------------
